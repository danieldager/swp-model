# %%
import os
import sys
import numpy as np
import pandas as pd
import seaborn as sns
from ast import literal_eval
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)

current = os.getcwd()
parent = os.path.dirname(current)
sys.path.append(parent)

converters = {
    "Word": str, 
    "Phonemes": literal_eval, 
    "No_Stress": literal_eval, 
    "Prediction": literal_eval,
    "H1": literal_eval, 
    "C1": literal_eval
}

# %%
# path = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s83_sn_ec/56/e_27/evaluation.csv"
path = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s4_sn_ec/96/d_66/evaluation.csv"
df = pd.read_csv(path, index_col=0, converters=converters)

total = len(df)
df = df[df['Edit_Distance'] > 0]
print(f"Error Rate: {len(df) / total:.2%}")

df = df[['Word', 'Condition', 'Phonemes', 'Prediction', 'Edit_Distance']]
# df = df[['Type', 'Sonority', 'Phonemes', 'Prediction']]
df
# Out:
# Error Rate: 11.58%
#              Word Condition                           Phonemes  \
# 7       obviously      RLCH       [AA, B, V, IY, AH, S, L, IY]
# 8      physically      RLCH       [F, IH, Z, IH, K, AH, L, IY]
# 10      perfectly      RLCH        [P, ER, F, AH, K, T, L, IY]
# 13      languages      RLCH   [L, AE, NG, G, W, AH, JH, AH, Z]
# 15     increasing      RLCH       [IH, N, K, R, IY, S, IH, NG]
# 17      framework      RLCH            [F, R, EY, M, W, ER, K]
# 31     technology      RLCH   [T, EH, K, N, AA, L, AH, JH, IY]
# 35    potentially      RLCH   [P, AH, T, EH, N, SH, AH, L, IY]
# 41    essentially      RLCH      [IH, S, EH, N, SH, AH, L, IY]
# 48      cambridge      RLCH           [K, EY, M, B, R, IH, JH]
# 52     functional      RLCH   [F, AH, NG, K, SH, AH, N, AH, L]
# 54       property      RLCH           [P, R, AA, P, ER, T, IY]
# 57     percentage      RLCH       [P, ER, S, EH, N, T, AH, JH]
# 60      legendary      RLCH   [L, EH, JH, AH, N, D, EH, R, IY]
# ...
