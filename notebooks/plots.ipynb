# %%
import os
import sys

current = os.getcwd()
parent = os.path.dirname(current)
sys.path.append(parent)

# %%
from ast import literal_eval

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option("display.max_rows", None)


converters = {
    "Word": str,
    "Phonemes": literal_eval,
    "No_Stress": literal_eval,
    "Prediction": literal_eval,
    "Error_Indices": literal_eval,
}

# %%
p1 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s1_sn_ec/75/control/evaluation.csv"
p2 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s4_sn_ec/96/control/evaluation.csv"
p3 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s5_sn_ec/93/control/evaluation.csv"
p4 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s37_sn_ec/94/control/evaluation.csv"
p5 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s45_sn_ec/58/control/evaluation.csv"
p6 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s68_sn_ec/95/control/evaluation.csv"
p7 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s70_sn_ec/92/control/evaluation.csv"
p8 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s83_sn_ec/56/control/evaluation.csv"
p9 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s95_sn_ec/93/control/evaluation.csv"
p10 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s96_sn_ec/82/control/evaluation.csv"

d1 = pd.read_csv(p1, index_col=0, converters=converters)
d2 = pd.read_csv(p2, index_col=0, converters=converters)
d3 = pd.read_csv(p3, index_col=0, converters=converters)
d4 = pd.read_csv(p4, index_col=0, converters=converters)
d5 = pd.read_csv(p5, index_col=0, converters=converters)
d6 = pd.read_csv(p6, index_col=0, converters=converters)
d7 = pd.read_csv(p7, index_col=0, converters=converters)
d8 = pd.read_csv(p8, index_col=0, converters=converters)
d9 = pd.read_csv(p9, index_col=0, converters=converters)
d10 = pd.read_csv(p10, index_col=0, converters=converters)

dfs = [d1, d2, d3, d4, d5, d6, d7, d8, d9, d10]

# %%
p1 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s1_sn_ec/75/e59/evaluation.csv"
p2 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s4_sn_ec/96/e66/evaluation.csv"
p3 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s5_sn_ec/93/e124/evaluation.csv"
p4 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s37_sn_ec/94/e10/evaluation.csv"
p5 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s45_sn_ec/58/e16/evaluation.csv"
p6 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s68_sn_ec/95/e66/evaluation.csv"
p7 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s70_sn_ec/92/e74/evaluation.csv"
p8 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s83_sn_ec/56/e29/evaluation.csv"
p9 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s95_sn_ec/93/e0/evaluation.csv"
p10 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s96_sn_ec/82/e20/evaluation.csv"

d1 = pd.read_csv(p1, index_col=0, converters=converters)
d2 = pd.read_csv(p2, index_col=0, converters=converters)
d3 = pd.read_csv(p3, index_col=0, converters=converters)
d4 = pd.read_csv(p4, index_col=0, converters=converters)
d5 = pd.read_csv(p5, index_col=0, converters=converters)
d6 = pd.read_csv(p6, index_col=0, converters=converters)
d7 = pd.read_csv(p7, index_col=0, converters=converters)
d8 = pd.read_csv(p8, index_col=0, converters=converters)
d9 = pd.read_csv(p9, index_col=0, converters=converters)
d10 = pd.read_csv(p10, index_col=0, converters=converters)

dfs = [d1, d2, d3, d4, d5, d6, d7, d8, d9, d10]

# %%
p1 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s1_sn_ec/75/e40/evaluation.csv"
p2 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s4_sn_ec/96/e112/evaluation.csv"
p3 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s5_sn_ec/93/e42/evaluation.csv"
p4 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s37_sn_ec/94/e68/evaluation.csv"
p5 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s45_sn_ec/58/e34/evaluation.csv"
p6 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s68_sn_ec/95/e44/evaluation.csv"
p7 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s70_sn_ec/92/e95/evaluation.csv"
p8 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s83_sn_ec/56/e58/evaluation.csv"
p9 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s95_sn_ec/93/e42/evaluation.csv"
p10 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s96_sn_ec/82/e30/evaluation.csv"

d1 = pd.read_csv(p1, index_col=0, converters=converters)
d2 = pd.read_csv(p2, index_col=0, converters=converters)
d3 = pd.read_csv(p3, index_col=0, converters=converters)
d4 = pd.read_csv(p4, index_col=0, converters=converters)
d5 = pd.read_csv(p5, index_col=0, converters=converters)
d6 = pd.read_csv(p6, index_col=0, converters=converters)
d7 = pd.read_csv(p7, index_col=0, converters=converters)
d8 = pd.read_csv(p8, index_col=0, converters=converters)
d9 = pd.read_csv(p9, index_col=0, converters=converters)
d10 = pd.read_csv(p10, index_col=0, converters=converters)

dfs = [d1, d2, d3, d4, d5, d6, d7, d8, d9, d10]

# %%
from swp.viz.test.length import plot_length_errors

big_df = pd.concat(dfs, ignore_index=True)
plot_length_errors(big_df, var="ci")

# %%
from swp.viz.test.position import plot_position_errors_smooth

big_df = pd.concat(dfs, ignore_index=True)
plot_position_errors_smooth(big_df, var="se")

# %%
from swp.viz.test.regressions import regression_plots

regression_plots(dfs)

# %%
p1 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s1_sn_ec/75/control/sonority.csv"
p2 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s4_sn_ec/96/control/sonority.csv"
p3 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s5_sn_ec/93/control/sonority.csv"
p4 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s37_sn_ec/94/control/sonority.csv"
p5 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s45_sn_ec/58/control/sonority.csv"
p6 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s68_sn_ec/95/control/sonority.csv"
p7 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s70_sn_ec/92/control/sonority.csv"
p8 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s83_sn_ec/56/control/sonority.csv"
p9 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s95_sn_ec/93/control/sonority.csv"
p10 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s96_sn_ec/82/control/sonority.csv"

d1 = pd.read_csv(p1, index_col=0, converters=converters)
d2 = pd.read_csv(p2, index_col=0, converters=converters)
d3 = pd.read_csv(p3, index_col=0, converters=converters)
d4 = pd.read_csv(p4, index_col=0, converters=converters)
d5 = pd.read_csv(p5, index_col=0, converters=converters)
d6 = pd.read_csv(p6, index_col=0, converters=converters)
d7 = pd.read_csv(p7, index_col=0, converters=converters)
d8 = pd.read_csv(p8, index_col=0, converters=converters)
d9 = pd.read_csv(p9, index_col=0, converters=converters)
d10 = pd.read_csv(p10, index_col=0, converters=converters)

dfs = [d1, d2, d3, d4, d5, d6, d7, d8, d9, d10]

# %%
p1 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s1_sn_ec/75/e59/sonority.csv"
p2 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s4_sn_ec/96/e66/sonority.csv"
p3 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s5_sn_ec/93/e124/sonority.csv"
p4 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s37_sn_ec/94/e10/sonority.csv"
p5 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s45_sn_ec/58/e16/sonority.csv"
p6 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s68_sn_ec/95/e66/sonority.csv"
p7 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s70_sn_ec/92/e74/sonority.csv"
p8 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s83_sn_ec/56/e29/sonority.csv"
p9 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s95_sn_ec/93/e0/sonority.csv"
p10 = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s96_sn_ec/82/e20/sonority.csv"

d1 = pd.read_csv(p1, index_col=0, converters=converters)
d2 = pd.read_csv(p2, index_col=0, converters=converters)
d3 = pd.read_csv(p3, index_col=0, converters=converters)
d4 = pd.read_csv(p4, index_col=0, converters=converters)
d5 = pd.read_csv(p5, index_col=0, converters=converters)
d6 = pd.read_csv(p6, index_col=0, converters=converters)
d7 = pd.read_csv(p7, index_col=0, converters=converters)
d8 = pd.read_csv(p8, index_col=0, converters=converters)
d9 = pd.read_csv(p9, index_col=0, converters=converters)
d10 = pd.read_csv(p10, index_col=0, converters=converters)

dfs = [d1, d2, d3, d4, d5, d6, d7, d8, d9, d10]

# %%
from swp.viz.test.sonority import plot_sonority_errors

big_df = pd.concat(dfs, ignore_index=True)
plot_sonority_errors(big_df, var="ci")

# %%
from swp.viz.embeddings import mlem_univariate

df_path = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s42_sn_ec/75/control/evaluation.csv"
df = pd.read_csv(df_path, index_col=0, converters=converters)

h_path = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1/b1024_l0.001_fall_s42_sn_ec/75/control/evaluation_h.npy"
h_emb = np.load(h_path)

# c_path = "../results/evaluation/Ua_LSTM_h128_l1_v42_d0.0_t0.0_s1~b2048_l0.001_fall_sn/epochs/75/control/evaluation_c.npy"
# c_emb = np.load(c_path)

# results_df = mlem_univariate(df, h_emb, "evaluation")
# results_df.to_csv("data/mlem_univariate.csv")
# Out:
# Neuron 128/128

# %%
df = pd.read_csv("data/mlem_univariate.csv", index_col=0)
# print Spearman values descending
print(df.sort_values("Spearman", ascending=True))
# Out:
#      Neuron         Feature  Importance  Spearman
# 147      36  Zipf_Frequency   -0.014871 -0.006979
# 146      36      Lexicality    0.000689 -0.006979
# 145      36      Morphology    0.000716 -0.006979
# 144      36          Length    0.005177 -0.006979
# 359      89  Zipf_Frequency   -0.006881 -0.004318
# 357      89          Length   -0.000425 -0.004318
# 356      89      Lexicality    0.002038 -0.004318
# 358      89      Morphology   -0.000624 -0.004318
# 204      51      Morphology   -0.000552 -0.003428
# 205      51          Length   -0.000645 -0.003428
# 206      51      Lexicality   -0.001505 -0.003428
# 207      51  Zipf_Frequency   -0.002645 -0.003428
# 154      38          Length   -0.002869 -0.003152
# 155      38      Lexicality   -0.002884 -0.003152
# 153      38      Morphology    0.000398 -0.003152
# 152      38  Zipf_Frequency    0.000965 -0.003152
# 434     108          Length   -0.000663  0.001533
# 435     108      Lexicality   -0.005471  0.001533
# 433     108      Morphology    0.000233  0.001533
# 432     108  Zipf_Frequency    0.007419  0.001533
# 292      73      Lexicality    0.004595  0.001840
# 293      73      Morphology    0.001666  0.001840
# 294      73          Length    0.001023  0.001840
# 295      73  Zipf_Frequency   -0.005044  0.001840
# 320      80          Length    0.005956  0.002486
# 321      80      Morphology    0.001017  0.002486
# 322      80      Lexicality   -0.001863  0.002486
# 323      80  Zipf_Frequency   -0.002005  0.002486
# 254      63      Morphology   -0.000895  0.002704
# 253      63  Zipf_Frequency    0.000002  0.002704
# 252      63          Length    0.005831  0.002704
# 255      63      Lexicality   -0.002155  0.002704
# 138      34      Morphology   -0.000487  0.003365
# 137      34          Length    0.002339  0.003365
# 136      34      Lexicality    0.003987  0.003365
# 139      34  Zipf_Frequency   -0.001825  0.003365
# 317      79      Lexicality    0.002686  0.003394
# 316      79          Length    0.004489  0.003394
# 318      79      Morphology   -0.000074  0.003394
# 319      79  Zipf_Frequency   -0.001757  0.003394
# 348      87      Lexicality    0.003602  0.004031
# 351      87  Zipf_Frequency   -0.001822  0.004031
# 349      87      Morphology    0.003438  0.004031
# 350      87          Length   -0.000136  0.004031
# 162      40      Morphology    0.001314  0.004081
# 163      40  Zipf_Frequency   -0.008302  0.004081
# 160      40          Length    0.008206  0.004081
# 161      40      Lexicality    0.004535  0.004081
# 248      62      Lexicality    0.002990  0.004261
# 249      62          Length    0.002959  0.004261
# 250      62      Morphology    0.000616  0.004261
# 251      62  Zipf_Frequency    0.000160  0.004261
# 109      27  Zipf_Frequency    0.001283  0.004390
# 108      27          Length    0.008058  0.004390
# 110      27      Morphology   -0.000257  0.004390
# 111      27      Lexicality   -0.002065  0.004390
# 96       24          Length    0.003862  0.005549
# 97       24      Lexicality    0.001955  0.005549
# 99       24  Zipf_Frequency   -0.000441  0.005549
# 98       24      Morphology    0.001238  0.005549
# 402     100      Morphology   -0.000229  0.007499
# 403     100      Lexicality   -0.000472  0.007499
# 400     100          Length    0.010162  0.007499
# 401     100  Zipf_Frequency   -0.000059  0.007499
# 101      25      Lexicality    0.004487  0.008057
# 100      25  Zipf_Frequency    0.004595  0.008057
# 103      25          Length   -0.001232  0.008057
# 102      25      Morphology    0.000686  0.008057
# 83       20  Zipf_Frequency   -0.003652  0.008679
# 82       20          Length   -0.001947  0.008679
# 81       20      Lexicality    0.004007  0.008679
# 80       20      Morphology    0.013058  0.008679
# 230      57      Lexicality    0.000387  0.009055
# 228      57          Length    0.006660  0.009055
# 229      57  Zipf_Frequency    0.005218  0.009055
# 231      57      Morphology   -0.000052  0.009055
# 4         1          Length    0.014722  0.009093
# 5         1      Lexicality    0.005517  0.009093
# 6         1      Morphology    0.002020  0.009093
# 7         1  Zipf_Frequency   -0.011917  0.009093
# 267      66  Zipf_Frequency   -0.013547  0.009202
# 264      66      Lexicality    0.017487  0.009202
# 265      66          Length    0.007443  0.009202
# 266      66      Morphology    0.000429  0.009202
# 75       18  Zipf_Frequency   -0.001151  0.009713
# 74       18      Morphology   -0.000260  0.009713
# 73       18          Length    0.005616  0.009713
# 72       18      Lexicality    0.007851  0.009713
# 275      68  Zipf_Frequency   -0.004114  0.009921
# 274      68      Morphology    0.001587  0.009921
# 273      68      Lexicality    0.003076  0.009921
# 272      68          Length    0.013172  0.009921
# 332      83          Length    0.008704  0.010047
# 335      83  Zipf_Frequency   -0.005369  0.010047
# 333      83      Lexicality    0.006876  0.010047
# 334      83      Morphology    0.002770  0.010047
# 459     114  Zipf_Frequency   -0.005322  0.010284
# 458     114      Morphology    0.001566  0.010284
# 457     114      Lexicality    0.006031  0.010284
# 456     114          Length    0.010663  0.010284
# 56       14      Morphology    0.004667  0.010610
# 59       14  Zipf_Frequency    0.002405  0.010610
# 57       14          Length    0.004162  0.010610
# 58       14      Lexicality    0.003749  0.010610
# 64       16          Length    0.009982  0.011641
# 65       16      Morphology    0.002756  0.011641
# 66       16  Zipf_Frequency    0.002588  0.011641
# 67       16      Lexicality   -0.000106  0.011641
# 233      58          Length    0.004865  0.012289
# 232      58      Morphology    0.007711  0.012289
# 234      58  Zipf_Frequency    0.002696  0.012289
# 235      58      Lexicality    0.001230  0.012289
# 411     102  Zipf_Frequency   -0.007435  0.013840
# 409     102      Lexicality    0.011749  0.013840
# 410     102      Morphology   -0.000869  0.013840
# 408     102          Length    0.015055  0.013840
# 179      44      Morphology   -0.000471  0.014365
# 177      44  Zipf_Frequency    0.004826  0.014365
# 176      44          Length    0.013913  0.014365
# 178      44      Lexicality    0.001349  0.014365
# 84       21      Lexicality    0.022141  0.014752
# 87       21  Zipf_Frequency   -0.009986  0.014752
# 85       21          Length    0.005024  0.014752
# 86       21      Morphology    0.001524  0.014752
# 291      72      Morphology   -0.000312  0.015052
# 290      72      Lexicality    0.001676  0.015052
# 289      72  Zipf_Frequency    0.003771  0.015052
# 288      72          Length    0.015663  0.015052
# 314      78      Morphology    0.005062  0.017292
# 312      78          Length    0.009153  0.017292
# 315      78  Zipf_Frequency    0.002371  0.017292
# 313      78      Lexicality    0.008639  0.017292
# 211      52      Morphology    0.001626  0.018393
# 210      52      Lexicality    0.002606  0.018393
# 209      52  Zipf_Frequency    0.005277  0.018393
# 208      52          Length    0.015825  0.018393
# 484     121          Length    0.018835  0.019902
# 486     121      Morphology    0.003006  0.019902
# 487     121  Zipf_Frequency   -0.005459  0.019902
# 485     121      Lexicality    0.009168  0.019902
# 431     107      Lexicality   -0.005088  0.020171
# 430     107      Morphology    0.001300  0.020171
# 429     107          Length    0.013238  0.020171
# 428     107  Zipf_Frequency    0.017327  0.020171
# 122      30  Zipf_Frequency    0.004185  0.020512
# 120      30          Length    0.018510  0.020512
# 121      30      Lexicality    0.004508  0.020512
# 123      30      Morphology    0.000264  0.020512
# 385      96      Lexicality    0.012154  0.020575
# 387      96  Zipf_Frequency   -0.011617  0.020575
# 386      96      Morphology    0.002355  0.020575
# 384      96          Length    0.022212  0.020575
# 43       10  Zipf_Frequency   -0.004105  0.021345
# 42       10      Morphology    0.003481  0.021345
# 41       10      Lexicality    0.011693  0.021345
# 40       10          Length    0.016461  0.021345
# 0         0          Length    0.014596  0.022637
# 1         0  Zipf_Frequency    0.012392  0.022637
# 2         0      Lexicality    0.003847  0.022637
# 3         0      Morphology    0.000629  0.022637
# 343      85  Zipf_Frequency   -0.007367  0.022859
# 342      85      Morphology    0.003032  0.022859
# 340      85          Length    0.020978  0.022859
# 341      85      Lexicality    0.011833  0.022859
# 363      90  Zipf_Frequency   -0.009684  0.023135
# 362      90      Morphology    0.001363  0.023135
# 361      90      Lexicality    0.012923  0.023135
# 360      90          Length    0.025267  0.023135
# 466     116      Morphology    0.005793  0.025372
# 464     116          Length    0.015067  0.025372
# 465     116      Lexicality    0.009128  0.025372
# 467     116  Zipf_Frequency    0.004474  0.025372
# 284      71          Length    0.020706  0.026415
# 285      71      Lexicality    0.015227  0.026415
# 287      71  Zipf_Frequency   -0.000269  0.026415
# 286      71      Morphology    0.000900  0.026415
# 491     122      Morphology    0.000713  0.026796
# 490     122  Zipf_Frequency    0.007038  0.026796
# 489     122      Lexicality    0.007519  0.026796
# 488     122          Length    0.020372  0.026796
# 79       19      Morphology   -0.000814  0.028171
# 78       19      Lexicality    0.002825  0.028171
# 77       19  Zipf_Frequency    0.004880  0.028171
# 76       19          Length    0.028416  0.028171
# 90       22      Morphology    0.001910  0.028413
# 89       22      Lexicality    0.018580  0.028413
# 88       22          Length    0.018974  0.028413
# 91       22  Zipf_Frequency   -0.002827  0.028413
# 164      41          Length    0.027152  0.028415
# 165      41      Lexicality    0.013362  0.028415
# 166      41      Morphology    0.001403  0.028415
# 167      41  Zipf_Frequency   -0.005708  0.028415
# 416     104          Length    0.017132  0.030325
# 417     104  Zipf_Frequency    0.016863  0.030325
# 418     104      Lexicality    0.007148  0.030325
# 419     104      Morphology    0.000482  0.030325
# 220      55      Lexicality    0.020958  0.030613
# 221      55          Length    0.013807  0.030613
# 222      55      Morphology    0.005398  0.030613
# 223      55  Zipf_Frequency    0.001367  0.030613
# 309      77      Lexicality    0.013883  0.031287
# 308      77          Length    0.020590  0.031287
# 311      77      Morphology    0.000426  0.031287
# 310      77  Zipf_Frequency    0.007153  0.031287
# 68       17          Length    0.029411  0.031747
# 69       17      Lexicality    0.010073  0.031747
# 70       17  Zipf_Frequency    0.002311  0.031747
# 71       17      Morphology   -0.000320  0.031747
# 462     115  Zipf_Frequency    0.000999  0.031767
# 461     115      Lexicality    0.004883  0.031767
# 460     115          Length    0.034086  0.031767
# 463     115      Morphology   -0.000899  0.031767
# 246      61          Length    0.013032  0.034320
# 245      61      Morphology    0.013631  0.034320
# 244      61  Zipf_Frequency    0.015313  0.034320
# 247      61      Lexicality    0.005913  0.034320
# 212      53          Length    0.023691  0.034728
# 213      53      Lexicality    0.017348  0.034728
# 214      53  Zipf_Frequency    0.005906  0.034728
# 215      53      Morphology   -0.000162  0.034728
# 183      45      Lexicality    0.003286  0.035188
# 181      45  Zipf_Frequency    0.010220  0.035188
# 180      45          Length    0.025750  0.035188
# 182      45      Morphology    0.006431  0.035188
# 448     112          Length    0.037061  0.044573
# 449     112      Lexicality    0.012350  0.044573
# 450     112  Zipf_Frequency    0.004433  0.044573
# 451     112      Morphology    0.004358  0.044573
# 500     125          Length    0.028328  0.044949
# 501     125      Morphology    0.012516  0.044949
# 502     125  Zipf_Frequency    0.009440  0.044949
# 503     125      Lexicality    0.006985  0.044949
# 151      37  Zipf_Frequency    0.006108  0.051095
# 150      37      Morphology    0.006547  0.051095
# 149      37      Lexicality    0.013443  0.051095
# 148      37          Length    0.041006  0.051095
# 373      93      Lexicality    0.022292  0.051153
# 372      93          Length    0.036603  0.051153
# 375      93      Morphology    0.003158  0.051153
# 374      93  Zipf_Frequency    0.008278  0.051153
# 276      69          Length    0.059616  0.052787
# 277      69      Lexicality    0.007539  0.052787
# 278      69      Morphology    0.000603  0.052787
# 279      69  Zipf_Frequency   -0.000114  0.052787
# 62       15      Lexicality    0.011828  0.052904
# 61       15  Zipf_Frequency    0.022665  0.052904
# 60       15          Length    0.033100  0.052904
# 63       15      Morphology    0.004171  0.052904
# 14        3      Morphology   -0.001224  0.054938
# 13        3  Zipf_Frequency    0.002054  0.054938
# 12        3          Length    0.070482  0.054938
# 15        3      Lexicality   -0.004447  0.054938
# 424     106          Length    0.060282  0.055700
# 426     106      Morphology   -0.001118  0.055700
# 425     106      Lexicality    0.017575  0.055700
# 427     106  Zipf_Frequency   -0.008662  0.055700
# 377      94  Zipf_Frequency    0.015692  0.056040
# 376      94          Length    0.044663  0.056040
# 378      94      Lexicality    0.008281  0.056040
# 379      94      Morphology    0.005814  0.056040
# 392      98          Length    0.040263  0.056315
# 393      98      Lexicality    0.017263  0.056315
# 394      98  Zipf_Frequency    0.015080  0.056315
# 395      98      Morphology    0.002833  0.056315
# 170      42      Lexicality    0.011006  0.058156
# 171      42      Morphology    0.001261  0.058156
# 168      42  Zipf_Frequency    0.038440  0.058156
# 169      42          Length    0.030816  0.058156
# 399      99      Morphology    0.000873  0.065544
# 396      99          Length    0.046085  0.065544
# 397      99  Zipf_Frequency    0.021628  0.065544
# 398      99      Lexicality    0.019025  0.065544
# 35        8      Morphology    0.000306  0.067576
# 34        8      Lexicality    0.011183  0.067576
# 32        8          Length    0.058490  0.067576
# 33        8  Zipf_Frequency    0.019801  0.067576
# 131      32  Zipf_Frequency    0.006213  0.067726
# 130      32      Morphology    0.008593  0.067726
# 129      32      Lexicality    0.016072  0.067726
# 128      32          Length    0.056859  0.067726
# 11        2      Morphology    0.000462  0.068483
# 10        2      Lexicality    0.018353  0.068483
# 9         2  Zipf_Frequency    0.019387  0.068483
# 8         2          Length    0.052685  0.068483
# 48       12          Length    0.056292  0.069087
# 49       12  Zipf_Frequency    0.018329  0.069087
# 50       12      Lexicality    0.012035  0.069087
# 51       12      Morphology    0.005351  0.069087
# 479     119      Morphology    0.002642  0.077834
# 476     119          Length    0.069379  0.077834
# 477     119  Zipf_Frequency    0.022143  0.077834
# 478     119      Lexicality    0.008532  0.077834
# 509     127      Lexicality    0.010850  0.079181
# 508     127          Length    0.082454  0.079181
# 510     127  Zipf_Frequency    0.005898  0.079181
# 511     127      Morphology    0.000084  0.079181
# 365      91  Zipf_Frequency    0.028678  0.083978
# 366      91      Lexicality    0.015328  0.083978
# 367      91      Morphology   -0.000337  0.083978
# 364      91          Length    0.067091  0.083978
# 499     124      Morphology    0.000630  0.084102
# 497     124      Lexicality    0.016498  0.084102
# 496     124          Length    0.087956  0.084102
# 498     124  Zipf_Frequency    0.001911  0.084102
# 156      39          Length    0.093571  0.086247
# 157      39      Lexicality    0.014302  0.086247
# 158      39      Morphology    0.000306  0.086247
# 159      39  Zipf_Frequency   -0.001392  0.086247
# 329      82  Zipf_Frequency    0.027359  0.092300
# 331      82      Morphology    0.000071  0.092300
# 330      82      Lexicality    0.025206  0.092300
# 328      82          Length    0.069754  0.092300
# 420     105          Length    0.073561  0.095799
# 421     105  Zipf_Frequency    0.030433  0.095799
# 422     105      Lexicality    0.019239  0.095799
# 423     105      Morphology    0.006061  0.095799
# 202      50      Lexicality    0.013536  0.097276
# 200      50          Length    0.091226  0.097276
# 203      50      Morphology    0.002227  0.097276
# 201      50  Zipf_Frequency    0.017947  0.097276
# 300      75          Length    0.074884  0.100186
# 302      75      Lexicality    0.022393  0.100186
# 303      75      Morphology    0.001277  0.100186
# 301      75  Zipf_Frequency    0.035128  0.100186
# 368      92          Length    0.070444  0.100655
# 369      92      Lexicality    0.030431  0.100655
# 370      92  Zipf_Frequency    0.028719  0.100655
# 371      92      Morphology    0.005494  0.100655
# 197      49  Zipf_Frequency    0.035015  0.104054
# 198      49      Lexicality    0.019407  0.104054
# 199      49      Morphology    0.000016  0.104054
# 196      49          Length    0.083649  0.104054
# 258      64  Zipf_Frequency    0.022703  0.104310
# 257      64      Lexicality    0.025907  0.104310
# 259      64      Morphology    0.007757  0.104310
# 256      64          Length    0.077712  0.104310
# 441     110  Zipf_Frequency    0.034299  0.105261
# 442     110      Lexicality    0.021743  0.105261
# 440     110          Length    0.083578  0.105261
# 443     110      Morphology    0.001121  0.105261
# 124      31          Length    0.104168  0.108426
# 127      31      Morphology    0.000129  0.108426
# 126      31  Zipf_Frequency    0.009425  0.108426
# 125      31      Lexicality    0.023148  0.108426
# 191      47      Morphology    0.002478  0.109749
# 190      47  Zipf_Frequency    0.012263  0.109749
# 189      47      Lexicality    0.021312  0.109749
# 188      47          Length    0.103081  0.109749
# 388      97          Length    0.091287  0.112656
# 389      97  Zipf_Frequency    0.039432  0.112656
# 390      97      Lexicality    0.015184  0.112656
# 391      97      Morphology    0.001048  0.112656
# 27        6      Morphology   -0.000205  0.120086
# 26        6      Lexicality    0.013024  0.120086
# 24        6          Length    0.100467  0.120086
# 25        6  Zipf_Frequency    0.044556  0.120086
# 347      86      Morphology    0.009046  0.121154
# 346      86      Lexicality    0.012875  0.121154
# 345      86  Zipf_Frequency    0.036220  0.121154
# 344      86          Length    0.097410  0.121154
# 507     126      Morphology    0.000775  0.136574
# 506     126      Lexicality    0.026036  0.136574
# 505     126  Zipf_Frequency    0.040700  0.136574
# 504     126          Length    0.106321  0.136574
# 236      59          Length    0.124675  0.153487
# 237      59  Zipf_Frequency    0.048065  0.153487
# 238      59      Lexicality    0.034293  0.153487
# 239      59      Morphology   -0.000028  0.153487
# 105      26  Zipf_Frequency    0.058574  0.155884
# 107      26      Morphology    0.001839  0.155884
# 106      26      Lexicality    0.026802  0.155884
# 104      26          Length    0.117462  0.155884
# 282      70      Lexicality    0.036423  0.157051
# 281      70  Zipf_Frequency    0.051297  0.157051
# 283      70      Morphology    0.002718  0.157051
# 280      70          Length    0.117675  0.157051
# 46       11      Lexicality    0.022562  0.157390
# 45       11  Zipf_Frequency    0.033009  0.157390
# 47       11      Morphology    0.000614  0.157390
# 44       11          Length    0.139278  0.157390
# 475     118      Morphology    0.000128  0.158294
# 474     118  Zipf_Frequency    0.005560  0.158294
# 473     118      Lexicality    0.010817  0.158294
# 472     118          Length    0.168072  0.158294
# 184      46          Length    0.150128  0.175193
# 185      46  Zipf_Frequency    0.046543  0.175193
# 186      46      Lexicality    0.024163  0.175193
# 187      46      Morphology    0.000556  0.175193
# 268      67          Length    0.151374  0.176947
# 269      67  Zipf_Frequency    0.042789  0.176947
# 271      67      Morphology    0.001091  0.176947
# 270      67      Lexicality    0.024536  0.176947
# 298      74  Zipf_Frequency    0.023709  0.186913
# 296      74          Length    0.166735  0.186913
# 297      74      Lexicality    0.037586  0.186913
# 299      74      Morphology    0.000067  0.186913
# 52       13          Length    0.168876  0.197323
# 53       13  Zipf_Frequency    0.062057  0.197323
# 54       13      Lexicality    0.015116  0.197323
# 55       13      Morphology    0.001582  0.197323
# 327      81      Morphology    0.001069  0.202585
# 326      81      Lexicality    0.037801  0.202585
# 325      81  Zipf_Frequency    0.041930  0.202585
# 324      81          Length    0.174178  0.202585
# 439     109      Morphology   -0.000183  0.203018
# 437     109  Zipf_Frequency    0.049082  0.203018
# 436     109          Length    0.183915  0.203018
# 438     109      Lexicality    0.021101  0.203018
# 224      56          Length    0.194732  0.207817
# 225      56  Zipf_Frequency    0.027542  0.207817
# 226      56      Lexicality    0.020875  0.207817
# 227      56      Morphology    0.005259  0.207817
# 140      35          Length    0.218184  0.230179
# 141      35  Zipf_Frequency    0.033516  0.230179
# 142      35      Lexicality    0.019669  0.230179
# 143      35      Morphology    0.002495  0.230179
# 262      65      Lexicality    0.037217  0.232426
# 263      65      Morphology    0.000688  0.232426
# 261      65  Zipf_Frequency    0.051681  0.232426
# 260      65          Length    0.196559  0.232426
# 306      76  Zipf_Frequency    0.003859  0.234753
# 304      76          Length    0.243898  0.234753
# 307      76      Morphology   -0.000197  0.234753
# 305      76      Lexicality    0.007995  0.234753
# 336      84          Length    0.199296  0.237384
# 337      84  Zipf_Frequency    0.063738  0.237384
# 338      84      Lexicality    0.031722  0.237384
# 339      84      Morphology    0.000329  0.237384
# 38        9      Lexicality    0.035137  0.237935
# 39        9      Morphology    0.001082  0.237935
# 36        9          Length    0.202830  0.237935
# 37        9  Zipf_Frequency    0.053084  0.237935
# 116      29          Length    0.217661  0.246121
# 117      29  Zipf_Frequency    0.041596  0.246121
# 118      29      Lexicality    0.029995  0.246121
# 119      29      Morphology    0.002143  0.246121
# 455     113      Morphology    0.000243  0.248126
# 452     113          Length    0.216716  0.248126
# 454     113      Lexicality    0.027062  0.248126
# 453     113  Zipf_Frequency    0.059520  0.248126
# 495     123      Morphology    0.002399  0.253944
# 494     123      Lexicality    0.037847  0.253944
# 493     123  Zipf_Frequency    0.073996  0.253944
# 492     123          Length    0.204573  0.253944
# 471     117      Morphology    0.000322  0.261806
# 469     117  Zipf_Frequency    0.056163  0.261806
# 470     117      Lexicality    0.043639  0.261806
# 468     117          Length    0.229606  0.261806
# 483     120      Morphology    0.001231  0.275324
# 480     120          Length    0.236038  0.275324
# 482     120      Lexicality    0.038017  0.275324
# 481     120  Zipf_Frequency    0.059920  0.275324
# 22        5      Lexicality    0.021734  0.276619
# 23        5      Morphology    0.001337  0.276619
# 20        5          Length    0.250091  0.276619
# 21        5  Zipf_Frequency    0.048570  0.276619
# 240      60          Length    0.239527  0.277592
# 243      60      Morphology    0.000884  0.277592
# 242      60      Lexicality    0.037805  0.277592
# 241      60  Zipf_Frequency    0.058266  0.277592
# 407     101      Morphology   -0.000533  0.278104
# 406     101      Lexicality    0.022860  0.278104
# 405     101  Zipf_Frequency    0.031063  0.278104
# 404     101          Length    0.267202  0.278104
# 93       23  Zipf_Frequency    0.073074  0.281204
# 92       23          Length    0.240006  0.281204
# 94       23      Lexicality    0.039152  0.281204
# 95       23      Morphology    0.001671  0.281204
# 135      33      Morphology    0.001556  0.284051
# 133      33  Zipf_Frequency    0.037596  0.284051
# 134      33      Lexicality    0.031984  0.284051
# 132      33          Length    0.257510  0.284051
# 29        7  Zipf_Frequency    0.050158  0.294313
# 28        7          Length    0.259557  0.294313
# 31        7      Morphology    0.004033  0.294313
# 30        7      Lexicality    0.025841  0.294313
# 216      54          Length    0.271831  0.294577
# 217      54  Zipf_Frequency    0.042751  0.294577
# 218      54      Lexicality    0.022166  0.294577
# 219      54      Morphology    0.001425  0.294577
# 193      48  Zipf_Frequency    0.062747  0.296476
# 192      48          Length    0.257797  0.296476
# 195      48      Morphology    0.001407  0.296476
# 194      48      Lexicality    0.030363  0.296476
# 175      43      Morphology    0.000885  0.301568
# 172      43          Length    0.267389  0.301568
# 173      43  Zipf_Frequency    0.058842  0.301568
# 174      43      Lexicality    0.029498  0.301568
# 413     103  Zipf_Frequency    0.053714  0.317034
# 412     103          Length    0.291624  0.317034
# 415     103      Morphology    0.000060  0.317034
# 414     103      Lexicality    0.033622  0.317034
# 19        4      Morphology    0.000667  0.371738
# 18        4      Lexicality    0.017785  0.371738
# 17        4  Zipf_Frequency    0.050877  0.371738
# 16        4          Length    0.341962  0.371738
# 382      95      Lexicality    0.021547  0.389831
# 381      95  Zipf_Frequency    0.025608  0.389831
# 380      95          Length    0.372565  0.389831
# 383      95      Morphology    0.003630  0.389831
# 113      28  Zipf_Frequency    0.035343  0.465578
# 112      28          Length    0.441942  0.465578
# 115      28      Morphology    0.002561  0.465578
# 114      28      Lexicality    0.017087  0.465578
# 446     111      Lexicality    0.009631  0.524088
# 445     111  Zipf_Frequency    0.024162  0.524088
# 447     111      Morphology    0.001758  0.524088
# 444     111          Length    0.508563  0.524088
# 352      88          Length    0.609665  0.615002
# 353      88  Zipf_Frequency    0.010344  0.615002
# 354      88      Lexicality    0.005187  0.615002
# 355      88      Morphology    0.000590  0.615002

# %%
from swp.viz.embeddings import find_best_n_clusters

df = pd.read_csv("data/mlem_univariate.csv", index_col=0)
df = df[(df["Importance"] > 0) & (df["Spearman"] > 0.003)]
# df["Importance"] /= np.sqrt(df["Spearman"])
df["Importance"] /= df["Spearman"]

pivot = df.copy()
pivot = pivot.pivot_table(index="Neuron", columns="Feature", values="Importance")
pivot = pivot.fillna(0)

best_num_clusters, clusters = find_best_n_clusters(pivot, min_clusters=2)
print(f"Optimal number of clusters: {best_num_clusters}")
pivot["Cluster"] = clusters
pivot = pivot.reset_index().rename(columns={"index": "Neuron"})
df = df.merge(pivot[["Neuron", "Cluster"]], on="Neuron")
# Out:
# Optimal number of clusters: 2

# %%
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
import seaborn as sns

df_m = df.copy()

# Compute cumulative sums per neuron for stacking
df_m = df_m.sort_values(["Neuron", "Importance"], ascending=[True, False])
df_m["cum_importance"] = df_m.groupby("Neuron")["Importance"].cumsum()
df_m["bottom"] = df_m["cum_importance"] - df_m["Importance"]

# Compute total importance per neuron.
neuron_totals = (
    df_m.groupby("Neuron")["Importance"]
    .sum()
    .reset_index()
    .rename(columns={"Importance": "total_importance"})
)

# Get unique neuron-level info (Neuron and Cluster) and merge totals.
neurons = df_m[["Neuron", "Cluster"]].drop_duplicates().reset_index(drop=True)
neurons = neurons.merge(neuron_totals, on="Neuron", how="left")

# Compute total importance per cluster and sort clusters descending.
cluster_totals = neurons.groupby("Cluster")["total_importance"].sum().reset_index()
cluster_totals = cluster_totals.sort_values(
    "total_importance", ascending=False
).reset_index(drop=True)

# Create a mapping from the original Cluster to a new cluster order
cluster_order_map = {
    old: new for new, old in enumerate(cluster_totals["Cluster"], start=1)
}
neurons["new_cluster"] = neurons["Cluster"].map(cluster_order_map)

# Sort neurons by new cluster order and then by total importance (or neuron id)
neurons = neurons.sort_values(
    ["new_cluster", "total_importance"], ascending=[True, False]
).reset_index(drop=True)
neurons["within_cluster_order"] = neurons.groupby("new_cluster").cumcount()

# Define a custom x-axis (unit_index) with gaps between clusters.
gap_size = 5  # adjust gap size as needed
offset_map = {}
current_offset = 0
for cl in sorted(neurons["new_cluster"].unique()):
    offset_map[cl] = current_offset
    count_in_cluster = neurons[neurons["new_cluster"] == cl].shape[0]
    current_offset += count_in_cluster + gap_size

neurons["unit_index"] = neurons["within_cluster_order"] + neurons["new_cluster"].map(
    offset_map
)

# Merge the custom unit_index back into the melted DataFrame.
df_m = df_m.merge(neurons[["Neuron", "unit_index"]], on="Neuron", how="left")

# Plot the stacked bars.
plt.figure(figsize=(22, 9))
ax = plt.gca()

# Use Seaborn's default "deep" palette for our features.
features = sorted(df_m["Feature"].unique())
palette = dict(zip(features, sns.color_palette("deep", len(features))))

# Draw each segment as a bar segment.
for _, row in df_m.iterrows():
    ax.bar(
        row["unit_index"],
        row["Importance"],
        bottom=row["bottom"],
        width=1,
        color=palette.get(row["Feature"], "gray"),
    )

# ax.set_xlabel("Neuron (with clusters sorted by total FI & gaps between clusters)")
ax.set_ylabel("Stacked Feature Importance", fontsize=20)
# ax.set_title("Stacked Feature Importance per Neuron")
plt.xticks([])  # Optionally hide x-tick labels

handles = [
    mlines.Line2D(
        [],
        [],
        color=palette[feat],
        marker="s",
        linestyle="None",
        markersize=10,
        label=feat,
    )
    for feat in features
]
plt.legend(handles=handles, title="Feature", fontsize=18, title_fontsize=20)
plt.show()
