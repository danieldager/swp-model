# %%
import os
import pandas as pd

import spacy
from g2p_en import G2p
from wordfreq import zipf_frequency

nlp = spacy.load('en_core_web_sm')
g2p = G2p()

pd.options.display.max_rows = 4000

# Process the hand-made evaluation datasets
def process_dataset(directory: str, is_real=True) -> pd.DataFrame:
    data = []
    for file in os.listdir(directory):
        if file.endswith('.csv'):
            name_parts = file.split('.')[0].split('_')
            df = pd.read_csv(os.path.join(directory, file))
            
            df['Lexicality'] = name_parts[1]
            df['Morph Complexity'] = name_parts[-1]

            if is_real: df['Frequency'] = name_parts[2]
            data.append(df)
    
    data = pd.concat(data, join="outer", ignore_index=True)
    return data

# NOTE: need to add morph structure to the dataset
# Add frequency, part of speech, and phonemes to the dataset
def clean_and_enrich_data(df: pd.DataFrame, is_real=True) -> pd.DataFrame:
    
    # Drop rows with no word value
    df = df.dropna(subset=['word'])
    
    # Rename columns
    df = df.rename(columns={
        'word': 'Word',
        'PoS': 'Part of Speech',
        'num letters': 'Length',
    })

    # Add Zipf Frequency and Part of Speech columns
    if is_real:
        df = df.drop(columns=['Number', 'percentile freq', 'morph structure'])
        df['Zipf Frequency'] = df['Word'].apply(lambda x: zipf_frequency(x, 'en'))
        df['Part of Speech'] = df['Word'].apply(lambda x: nlp(x)[0].pos_)
    
    # Add Phonemes column
    df["Phonemes"] = df["Word"].apply(g2p)
    
    return df

# Combine and reformat the real and pseudo word datasets
def get_evaluation_data():
    
    # Process real words
    real_words = process_dataset('../data/eval_dataset_real')
    real_words = clean_and_enrich_data(real_words)

    # Process pseudo words
    pseudo_words = process_dataset('../data/eval_dataset_pseudo', is_real=False)
    pseudo_words = clean_and_enrich_data(pseudo_words, is_real=False)

    # Combine datasets
    data = pd.concat([real_words, pseudo_words], join="outer", ignore_index=True)

    # Rearrange columns
    columns = ["Word", "Length", "Frequency", "Zipf Frequency", 
            "Morph Complexity", "Lexicality", "Part of Speech", "Phonemes"]
    data = data.reindex(columns=columns)

    # Isolate words and their phonemes
    real_words = real_words[['Word', 'Phonemes']]
    pseudo_words = pseudo_words[['Word', 'Phonemes']]
    
    return data, real_words, pseudo_words

# Get the evaluation data
data, real_words, pseudo_words = get_evaluation_data()
data
# Out:
#            Word  Length Frequency  Zipf Frequency Morph Complexity Lexicality  \
# 0       bathmat       7       low            1.55          complex       real
# 1       decoder       7       low            2.84          complex       real
# 2       defiant       7       low            3.21          complex       real
# 3       padlock       7       low            2.68          complex       real
# 4       immoral       7       low            3.46          complex       real
# 5       nonstop       7       low            3.37          complex       real
# 6       parasol       7       low            2.63          complex       real
# 7       reactor       7       low            3.83          complex       real
# 8       recycle       7       low            3.35          complex       real
# 9       reenact       7       low            2.42          complex       real
# 10      reliant       7       low            3.41          complex       real
# 11      toaster       7       low            3.33          complex       real
# 12      upstage       7       low            2.35          complex       real
# 13      weirder       7       low            3.02          complex       real
# 14      weirdly       7       low            3.06          complex       real
# 15     alienate       8       low            3.03          complex       real
# 16     birdcage       8       low            2.45          complex       real
# 17     fourthly       8       low            2.08          complex       real
# 18     hopeless       8       low            3.71          complex       real
# 19     impolite       8       low            2.62          complex       real
# 20     scissors       8       low            3.58          complex       real
# 21     outsmart       8       low            2.67          complex       real
# 22     overcook       8       low            2.18          complex       real
# 23     necklace       8       low            3.85          complex       real
# 24     solvable       8       low            2.58          complex       real
# 25     curtains       8       low            3.66          complex       real
# 26     trustful       8       low            2.05          complex       real
# 27     unicycle       8       low            2.37          complex       real
# 28     popsicle       8       low            2.82          complex       real
# 29     suitcase       8       low            3.55          complex       real
# 30    adaptable       9       low            3.12          complex       real
# 31    blueberry       9       low            3.30          complex       real
# 32    cornbread       9       low            2.72          complex       real
# 33    disembark       9       low            2.68          complex       real
# 34    drumstick       9       low            2.36          complex       real
# 35    formality       9       low            3.15          complex       real
# 36    hamburger       9       low            3.45          complex       real
# 37    reinforce       9       low            3.68          complex       real
# 38    tattooist       9       low            1.99          complex       real
# 39    underline       9       low            2.98          complex       real
# 40    pineapple       9       low            3.58          complex       real
# 41    unnatural       9       low            3.48          complex       real
# 42    weirdness       9       low            2.92          complex       real
# 43    wishfully       9       low            1.44          complex       real
# 44    womanizer       9       low            2.61          complex       real
# 45      amphora       7       low            2.21           simple       real
# 46      stutter       7       low            2.95           simple       real
# 47      giraffe       7       low            3.32           simple       real
# 48      compass       7       low            3.74           simple       real
# 49      frisbee       7       low            2.96           simple       real
# 50      whistle       7       low            3.88           simple       real
# 51      javelin       7       low            2.90           simple       real
# 52      jugular       7       low            2.78           simple       real
# 53      legible       7       low            2.80           simple       real
# 54      liqueur       7       low            2.81           simple       real
# 55      penguin       7       low            3.78           simple       real
# 56      sapient       7       low            2.10           simple       real
# 57      satchel       7       low            2.90           simple       real
# 58      savanna       7       low            2.83           simple       real
# 59      whither       7       low            2.52           simple       real
# 60     cassette       8       low            3.40           simple       real
# 61     fumigate       8       low            1.87           simple       real
# 62     gargoyle       8       low            2.63           simple       real
# 63     instinct       8       low            3.86           simple       real
# 64     trombone       8       low            2.97           simple       real
# 65     umbrella       8       low            3.89           simple       real
# 66     mushroom       8       low            3.63           simple       real
# 67     hedgehog       8       low            3.25           simple       real
# 68     persuade       8       low            3.82           simple       real
# 69     scrabble       8       low            3.04           simple       real
# 70     skeleton       8       low            3.80           simple       real
# 71     stimulus       8       low            3.82           simple       real
# 72     kangaroo       8       low            3.50           simple       real
# 73     syndrome       8       low            4.23           simple       real
# 74     eggplant       8       low            3.01           simple       real
# 75    butterfly       9       low            3.93           simple       real
# 76    avalanche       9       low            3.48           simple       real
# 77    blaspheme       9       low            2.16           simple       real
# 78    boomerang       9       low            3.06           simple       real
# 79    boulevard       9       low            3.70           simple       real
# 80    catalogue       9       low            3.91           simple       real
# 81    chameleon       9       low            3.10           simple       real
# 82    champagne       9       low            3.90           simple       real
# 83    embarrass       9       low            3.41           simple       real
# 84    etiquette       9       low            3.40           simple       real
# 85    hurricane       9       low            4.10           simple       real
# 86    neighbour       9       low            3.69           simple       real
# 87    reservoir       9       low            3.90           simple       real
# 88    threshold       9       low            4.03           simple       real
# 89    versatile       9       low            3.66           simple       real
# 90         arty       4       low            2.99          complex       real
# 91         dewy       4       low            2.64          complex       real
# 92         gory       4       low            2.98          complex       real
# 93         hath       4       low            3.62          complex       real
# 94         hewn       4       low            2.67          complex       real
# 95         idly       4       low            2.93          complex       real
# 96         mugs       4       low            3.24          complex       real
# 97         oxen       4       low            2.90          complex       real
# 98         pods       4       low            3.45          complex       real
# 99         redo       4       low            3.19          complex       real
# 100        sows       4       low            2.59          complex       real
# 101        unto       4       low            3.96          complex       real
# 102        urns       4       low            2.71          complex       real
# 103        wiry       4       low            2.51          complex       real
# 104       befit       5       low            2.07          complex       real
# 105       combs       5       low            3.17          complex       real
# 106       debug       5       low            2.86          complex       real
# 107       enact       5       low            3.43          complex       real
# 108       ruler       5       low            3.84          complex       real
# 109       mixer       5       low            3.50          complex       real
# 110       odder       5       low            2.10          complex       real
# 111       paler       5       low            2.87          complex       real
# 112       renew       5       low            3.73          complex       real
# 113       repay       5       low            3.66          complex       real
# 114       reset       5       low            3.83          complex       real
# 115       shyly       5       low            2.42          complex       real
# 116       skier       5       low            3.20          complex       real
# 117       unzip       5       low            2.55          complex       real
# 118       wetly       5       low            1.41          complex       real
# 119      bowtie       6       low            2.40          complex       real
# 120      exhale       6       low            3.11          complex       real
# 121      heroic       6       low            3.84          complex       real
# 122      inhale       6       low            3.25          complex       real
# 123      pencil       6       low            3.95          complex       real
# 124      orally       6       low            3.12          complex       real
# 125      grapes       6       low            3.73          complex       real
# 126      faucet       6       low            3.07          complex       real
# 127      shears       6       low            2.90          complex       real
# 128      softly       6       low            3.77          complex       real
# 129      shells       6       low            3.93          complex       real
# 130      unreal       6       low            3.59          complex       real
# 131      uphill       6       low            3.38          complex       real
# 132      warmer       6       low            3.76          complex       real
# 133      yearly       6       low            3.88          complex       real
# 134        foot       4      high            4.87           simple       real
# 135        ally       4      high            4.10           simple       real
# 136        back       4      high            6.04           simple       real
# 137        iron       4      high            4.74           simple       real
# 138        dare       4      high            4.31           simple       real
# 139        dumb       4      high            4.54           simple       real
# 140        bear       4      high            4.71           simple       real
# 141        goat       4      high            4.02           simple       real
# 142        hack       4      high            4.05           simple       real
# 143        tank       4      high            4.57           simple       real
# 144        mild       4      high            4.11           simple       real
# 145        belt       4      high            4.42           simple       real
# 146        rain       4      high            4.71           simple       real
# 147        shot       4      high            5.22           simple       real
# 148        west       4      high            5.29           simple       real
# 149       fence       5      high            4.21           simple       real
# 150       truck       5      high            4.64           simple       real
# 151       drone       5      high            4.00           simple       real
# 152       house       5      high            5.71           simple       real
# 153       large       5      high            5.39           simple       real
# 154       least       5      high            5.44           simple       real
# 155       money       5      high            5.64           simple       real
# 156       piano       5      high            4.31           simple       real
# 157       swing       5      high            4.34           simple       real
# 158       radio       5      high            5.01           simple       real
# 159       sword       5      high            4.37           simple       real
# 160       phone       5      high            5.30           simple       real
# 161       quite       5      high            5.29           simple       real
# 162       knife       5      high            4.41           simple       real
# 163       salad       5      high            4.15           simple       real
# 164      wallet       6      high            4.15           simple       real
# 165      engine       6      high            4.84           simple       real
# 166      enough       6      high            5.54           simple       real
# 167      family       6      high            5.66           simple       real
# 168      guitar       6      high            4.48           simple       real
# 169      govern       6      high            3.67           simple       real
# 170      little       6      high            5.75           simple       real
# 171      jersey       6      high            4.66           simple       real
# 172      cherry       6      high            4.18           simple       real
# 173      school       6      high            5.71           simple       real
# 174      simple       6      high            5.08           simple       real
# 175      strong       6      high            5.22           simple       real
# 176      camera       6      high            4.87           simple       real
# 177      target       6      high            4.82           simple       real
# 178      window       6      high            4.80           simple       real
# 179     captain       7      high            4.89           simple       real
# 180     despite       7      high            5.00           simple       real
# 181     gravity       7      high            4.21           simple       real
# 182     horizon       7      high            4.07           simple       real
# 183     inspire       7      high            4.00           simple       real
# 184     journey       7      high            4.65           simple       real
# 185     kitchen       7      high            4.65           simple       real
# 186     library       7      high            4.86           simple       real
# 187     natural       7      high            5.11           simple       real
# 188     rainbow       7      high            4.07           simple       real
# 189     shallow       7      high            4.04           simple       real
# 190     strange       7      high            4.64           simple       real
# 191     vaccine       7      high            4.00           simple       real
# 192     village       7      high            4.82           simple       real
# 193     missile       7      high            4.14           simple       real
# 194    absolute       8      high            4.54           simple       real
# 195   aluminium       8      high            3.73           simple       real
# 196    calendar       8      high            4.30           simple       real
# 197    elephant       8      high            4.08           simple       real
# 198    gorgeous       8      high            4.35           simple       real
# 199    hospital       8      high            5.07           simple       real
# 200    medicine       8      high            4.73           simple       real
# 201    mountain       8      high            4.73           simple       real
# 202    remember       8      high            5.38           simple       real
# 203    sandwich       8      high            4.13           simple       real
# 204    shoulder       8      high            4.50           simple       real
# 205    straight       8      high            5.04           simple       real
# 206    together       8      high            5.46           simple       real
# 207    treasure       8      high            4.17           simple       real
# 208    exercise       8      high            4.68           simple       real
# 209   algorithm       9      high            4.02           simple       real
# 210   aluminium       9      high            3.73           simple       real
# 211   architect       9      high            4.08           simple       real
# 212   automatic       9      high            4.36           simple       real
# 213   challenge       9      high            4.88           simple       real
# 214   character       9      high            5.11           simple       real
# 215   chocolate       9      high            4.49           simple       real
# 216   desperate       9      high            4.32           simple       real
# 217   emergency       9      high            4.72           simple       real
# 218   establish       9      high            4.46           simple       real
# 219   hurricane       9      high            4.10           simple       real
# 220   immediate       9      high            4.52           simple       real
# 221   peninsula       9      high            4.03           simple       real
# 222   satellite       9      high            4.33           simple       real
# 223   surrender       9      high            4.09           simple       real
# 224        ajar       4       low            2.57           simple       real
# 225        balk       4       low            2.72           simple       real
# 226        bark       4       low            3.85           simple       real
# 227        rake       4       low            3.38           simple       real
# 228        frog       4       low            3.89           simple       real
# 229        glee       4       low            3.49           simple       real
# 230        heft       4       low            2.75           simple       real
# 231        hymn       4       low            3.61           simple       real
# 232        lore       4       low            3.55           simple       real
# 233        sock       4       low            3.61           simple       real
# 234        peel       4       low            3.80           simple       real
# 235        quay       4       low            3.26           simple       real
# 236        quip       4       low            2.67           simple       real
# 237        wane       4       low            2.83           simple       real
# 238        zest       4       low            3.19           simple       real
# 239       acorn       5       low            3.08           simple       real
# 240       broom       5       low            3.42           simple       real
# 241       scarf       5       low            3.68           simple       real
# 242       glove       5       low            3.73           simple       real
# 243       easel       5       low            2.68           simple       real
# 244       hoist       5       low            3.12           simple       real
# 245       leery       5       low            2.58           simple       real
# 246       lithe       5       low            2.48           simple       real
# 247       camel       5       low            3.64           simple       real
# 248       mirth       5       low            2.62           simple       real
# 249       quill       5       low            3.11           simple       real
# 250       scour       5       low            2.97           simple       real
# 251       clown       5       low            3.93           simple       real
# 252       vault       5       low            3.90           simple       real
# 253       yacht       5       low            3.82           simple       real
# 254      arcane       6       low            2.99           simple       real
# 255      beetle       6       low            3.53           simple       real
# 256      bullet       6       low            4.24           simple       real
# 257      castle       6       low            4.45           simple       real
# 258      citrus       6       low            3.58           simple       real
# 259      frivol       6       low            0.00           simple       real
# 260      frugal       6       low            3.11           simple       real
# 261      mingle       6       low            3.21           simple       real
# 262      needle       6       low            3.98           simple       real
# 263      peddle       6       low            2.76           simple       real
# 264      puzzle       6       low            3.96           simple       real
# 265      quiver       6       low            2.84           simple       real
# 266      ramble       6       low            2.85           simple       real
# 267      writhe       6       low            2.24           simple       real
# 268      kettle       6       low            3.54           simple       real
# 269     anxiety       7      high            4.45          complex       real
# 270     briefly       7      high            4.22          complex       real
# 271     careful       7      high            4.59          complex       real
# 272     coastal       7      high            4.19          complex       real
# 273     enabled       7      high            4.11          complex       real
# 274     endless       7      high            4.18          complex       real
# 275     farmers       7      high            4.43          complex       real
# 276     glasses       7      high            4.34          complex       real
# 277     genetic       7      high            4.34          complex       real
# 278     matches       7      high            4.59          complex       real
# 279     medical       7      high            5.16          complex       real
# 280     mixture       7      high            4.18          complex       real
# 281     officer       7      high            5.03          complex       real
# 282     society       7      high            5.17          complex       real
# 283     studied       7      high            4.49          complex       real
# 284    affected       8      high            4.64          complex       real
# 285    alliance       8      high            4.40          complex       real
# 286    clinical       8      high            4.51          complex       real
# 287    computer       8      high            4.97          complex       real
# 288    disagree       8      high            4.09          complex       real
# 289    dramatic       8      high            4.41          complex       real
# 290    football       8      high            5.11          complex       real
# 291    homeless       8      high            4.26          complex       real
# 292    included       8      high            5.03          complex       real
# 293    mentally       8      high            4.20          complex       real
# 294    northern       8      high            4.85          complex       real
# 295    pictures       8      high            4.92          complex       real
# 296    students       8      high            5.25          complex       real
# 297    ultimate       8      high            4.53          complex       real
# 298    warriors       8      high            4.30          complex       real
# 299   allegedly       9      high            4.06          complex       real
# 300   confirmed       9      high            4.67          complex       real
# 301   criminals       9      high            4.15          complex       real
# 302   currently       9      high            5.08          complex       real
# 303   departure       9      high            4.22          complex       real
# 304   disappear       9      high            4.09          complex       real
# 305   engineers       9      high            4.41          complex       real
# 306   important       9      high            5.44          complex       real
# 307   overnight       9      high            4.19          complex       real
# 308   political       9      high            5.29          complex       real
# 309   pollution       9      high            4.20          complex       real
# 310   receiving       9      high            4.59          complex       real
# 311   scientist       9      high            4.21          complex       real
# 312   seriously       9      high            4.94          complex       real
# 313   wonderful       9      high            4.85          complex       real
# 314        axis       4      high            4.02          complex       real
# 315        cuts       4      high            4.42          complex       real
# 316        dies       4      high            4.41          complex       real
# 317        easy       4      high            5.29          complex       real
# 318        into       4      high            6.11          complex       real
# 319        jury       4      high            4.49          complex       real
# 320        lets       4      high            4.51          complex       real
# 321        liar       4      high            4.02          complex       real
# 322        nary       4      high            2.59          complex       real
# 323        sexy       4      high            4.42          complex       real
# 324        torn       4      high            4.08          complex       real
# 325        unit       4      high            4.95          complex       real
# 326        user       4      high            4.69          complex       real
# 327        wins       4      high            4.70          complex       real
# 328        worn       4      high            4.26          complex       real
# 329       actor       5      high            4.65          complex       real
# 330       among       5      high            5.31          complex       real
# 331      bloody       5      high            4.28          complex       real
# 332       blues       5      high            4.34          complex       real
# 333       boats       5      high            4.25          complex       real
# 334       bones       5      high            4.32          complex       real
# 335       daily       5      high            5.07          complex       real
# 336       early       5      high            5.43          complex       real
# 337       enjoy       5      high            5.09          complex       real
# 338       flags       5      high            4.09          complex       real
# 339       rings       5      high            4.33          complex       real
# 340       hurts       5      high            4.30          complex       real
# 341       lived       5      high            4.88          complex       real
# 342       birds       5      high            4.60          complex       real
# 343       stars       5      high            4.86          complex       real
# 344      across       6      high            5.25          complex       real
# 345      brains       6      high            4.07          complex       real
# 346      deaths       6      high            4.53          complex       real
# 347      flames       6      high            4.03          complex       real
# 348      hearts       6      high            4.44          complex       real
# 349      hotels       6      high            4.22          complex       real
# 350      iconic       6      high            4.13          complex       real
# 351      planes       6      high            4.16          complex       real
# 352      rarely       6      high            4.42          complex       real
# 353      stones       6      high            4.31          complex       real
# 354       sunny       6      high            4.07          complex       real
# 355      trains       6      high            4.27          complex       real
# 356      helmet       6      high            4.02          complex       real
# 357      wounds       6      high            4.07          complex       real
# 358      writes       6      high            4.36          complex       real
# 359     decycle       7       NaN             NaN          complex     pseudo
# 360     devably       7       NaN             NaN          complex     pseudo
# 361     devally       7       NaN             NaN          complex     pseudo
# 362     dislave       7       NaN             NaN          complex     pseudo
# 363     enslike       7       NaN             NaN          complex     pseudo
# 364     enspect       7       NaN             NaN          complex     pseudo
# 365     fatalue       7       NaN             NaN          complex     pseudo
# 366     fatcher       7       NaN             NaN          complex     pseudo
# 367     immover       7       NaN             NaN          complex     pseudo
# 368     inslave       7       NaN             NaN          complex     pseudo
# 369     inslike       7       NaN             NaN          complex     pseudo
# 370     modalue       7       NaN             NaN          complex     pseudo
# 371     movally       7       NaN             NaN          complex     pseudo
# 372     movalue       7       NaN             NaN          complex     pseudo
# 373     nonsory       7       NaN             NaN          complex     pseudo
# 374     nonstor       7       NaN             NaN          complex     pseudo
# 375     reactop       7       NaN             NaN          complex     pseudo
# 376     rearful       7       NaN             NaN          complex     pseudo
# 377     recoder       7       NaN             NaN          complex     pseudo
# 378     remoral       7       NaN             NaN          complex     pseudo
# 379     rensory       7       NaN             NaN          complex     pseudo
# 380     renstop       7       NaN             NaN          complex     pseudo
# 381     renstor       7       NaN             NaN          complex     pseudo
# 382     senewal       7       NaN             NaN          complex     pseudo
# 383     senstop       7       NaN             NaN          complex     pseudo
# 384     senstor       7       NaN             NaN          complex     pseudo
# 385     teactop       7       NaN             NaN          complex     pseudo
# 386     teactor       7       NaN             NaN          complex     pseudo
# 387     tenewal       7       NaN             NaN          complex     pseudo
# 388     tensory       7       NaN             NaN          complex     pseudo
# 389     tenstop       7       NaN             NaN          complex     pseudo
# 390     tenstor       7       NaN             NaN          complex     pseudo
# 391     watally       7       NaN             NaN          complex     pseudo
# 392     watalue       7       NaN             NaN          complex     pseudo
# 393    dishaven       8       NaN             NaN          complex     pseudo
# 394    dishonal       8       NaN             NaN          complex     pseudo
# 395    egoisely       8       NaN             NaN          complex     pseudo
# 396    egoistep       8       NaN             NaN          complex     pseudo
# 397    egoister       8       NaN             NaN          complex     pseudo
# 398    entanize       8       NaN             NaN          complex     pseudo
# 399    fourness       8       NaN             NaN          complex     pseudo
# 400    fourtive       8       NaN             NaN          complex     pseudo
# 401    impolder       8       NaN             NaN          complex     pseudo
# 402    overster       8       NaN             NaN          complex     pseudo
# 403    overstic       8       NaN             NaN          complex     pseudo
# 404    reimporm       8       NaN             NaN          complex     pseudo
# 405    reustful       8       NaN             NaN          complex     pseudo
# 406    reustler       8       NaN             NaN          complex     pseudo
# 407    searless       8       NaN             NaN          complex     pseudo
# 408    seasonor       8       NaN             NaN          complex     pseudo
# 409    sourtive       8       NaN             NaN          complex     pseudo
# 410    sprictep       8       NaN             NaN          complex     pseudo
# 411    spricter       8       NaN             NaN          complex     pseudo
# 412    sprindly       8       NaN             NaN          complex     pseudo
# 413    sprintep       8       NaN             NaN          complex     pseudo
# 414    strictep       8       NaN             NaN          complex     pseudo
# 415    strindly       8       NaN             NaN          complex     pseudo
# 416    strintep       8       NaN             NaN          complex     pseudo
# 417    strinter       8       NaN             NaN          complex     pseudo
# 418    teasonal       8       NaN             NaN          complex     pseudo
# 419    teasonor       8       NaN             NaN          complex     pseudo
# 420    trusable       8       NaN             NaN          complex     pseudo
# 421    trustler       8       NaN             NaN          complex     pseudo
# 422    uninfort       8       NaN             NaN          complex     pseudo
# 423    unkintep       8       NaN             NaN          complex     pseudo
# 424    unkinter       8       NaN             NaN          complex     pseudo
# 425    unshonal       8       NaN             NaN          complex     pseudo
# 426    unshonor       8       NaN             NaN          complex     pseudo
# 427    unwistep       8       NaN             NaN          complex     pseudo
# 428    unwister       8       NaN             NaN          complex     pseudo
# 429    unwistic       8       NaN             NaN          complex     pseudo
# 430    upholite       8       NaN             NaN          complex     pseudo
# 431    womangle       8       NaN             NaN          complex     pseudo
# 432    wrestful       8       NaN             NaN          complex     pseudo
# 433   clearally       9       NaN             NaN          complex     pseudo
# 434   cleartile       9       NaN             NaN          complex     pseudo
# 435   deodeness       9       NaN             NaN          complex     pseudo
# 436   deodenest       9       NaN             NaN          complex     pseudo
# 437   deodorism       9       NaN             NaN          complex     pseudo
# 438   deodorist       9       NaN             NaN          complex     pseudo
# 439   deoutsell       9       NaN             NaN          complex     pseudo
# 440   discreach       9       NaN             NaN          complex     pseudo
# 441   discreact       9       NaN             NaN          complex     pseudo
# 442   discreate       9       NaN             NaN          complex     pseudo
# 443   dishfully       9       NaN             NaN          complex     pseudo
# 444   disreport       9       NaN             NaN          complex     pseudo
# 445   distfully       9       NaN             NaN          complex     pseudo
# 446   formaline       9       NaN             NaN          complex     pseudo
# 447   immerlity       9       NaN             NaN          complex     pseudo
# 448   immerlize       9       NaN             NaN          complex     pseudo
# 449   immerpass       9       NaN             NaN          complex     pseudo
# 450   immersold       9       NaN             NaN          complex     pseudo
# 451   immertile       9       NaN             NaN          complex     pseudo
# 452   immorance       9       NaN             NaN          complex     pseudo
# 453   inferline       9       NaN             NaN          complex     pseudo
# 454   inferlity       9       NaN             NaN          complex     pseudo
# 455   inferpass       9       NaN             NaN          complex     pseudo
# 456   infersion       9       NaN             NaN          complex     pseudo
# 457   infersold       9       NaN             NaN          complex     pseudo
# 458   miscreact       9       NaN             NaN          complex     pseudo
# 459   misembark       9       NaN             NaN          complex     pseudo
# 460   misembody       9       NaN             NaN          complex     pseudo
# 461   mishfully       9       NaN             NaN          complex     pseudo
# 462   mistfully       9       NaN             NaN          complex     pseudo
# 463   normaline       9       NaN             NaN          complex     pseudo
# 464   overiline       9       NaN             NaN          complex     pseudo
# 465   overility       9       NaN             NaN          complex     pseudo
# 466   overilize       9       NaN             NaN          complex     pseudo
# 467   overreate       9       NaN             NaN          complex     pseudo
# 468   overredit       9       NaN             NaN          complex     pseudo
# 469   pitlessly       9       NaN             NaN          complex     pseudo
# 470   procreach       9       NaN             NaN          complex     pseudo
# 471   procreact       9       NaN             NaN          complex     pseudo
# 472   procredit       9       NaN             NaN          complex     pseudo
# 473   redefully       9       NaN             NaN          complex     pseudo
# 474   rederline       9       NaN             NaN          complex     pseudo
# 475   rederlity       9       NaN             NaN          complex     pseudo
# 476   rederlize       9       NaN             NaN          complex     pseudo
# 477   rederpass       9       NaN             NaN          complex     pseudo
# 478   redersion       9       NaN             NaN          complex     pseudo
# 479   redersold       9       NaN             NaN          complex     pseudo
# 480   redertile       9       NaN             NaN          complex     pseudo
# 481   reimbural       9       NaN             NaN          complex     pseudo
# 482   reinstake       9       NaN             NaN          complex     pseudo
# 483   reirdness       9       NaN             NaN          complex     pseudo
# 484   remindful       9       NaN             NaN          complex     pseudo
# 485   remistate       9       NaN             NaN          complex     pseudo
# 486   reodeness       9       NaN             NaN          complex     pseudo
# 487   reodenest       9       NaN             NaN          complex     pseudo
# 488   reodorism       9       NaN             NaN          complex     pseudo
# 489   reodorize       9       NaN             NaN          complex     pseudo
# 490   reodormly       9       NaN             NaN          complex     pseudo
# 491   steriline       9       NaN             NaN          complex     pseudo
# 492   sterreach       9       NaN             NaN          complex     pseudo
# 493   sterreact       9       NaN             NaN          complex     pseudo
# 494   sterreate       9       NaN             NaN          complex     pseudo
# 495   sterredit       9       NaN             NaN          complex     pseudo
# 496   tattooism       9       NaN             NaN          complex     pseudo
# 497   tensenest       9       NaN             NaN          complex     pseudo
# 498   tuneflate       9       NaN             NaN          complex     pseudo
# 499   undeflate       9       NaN             NaN          complex     pseudo
# 500   undefully       9       NaN             NaN          complex     pseudo
# 501   underlity       9       NaN             NaN          complex     pseudo
# 502   undersion       9       NaN             NaN          complex     pseudo
# 503   undertile       9       NaN             NaN          complex     pseudo
# 504   unearally       9       NaN             NaN          complex     pseudo
# 505   unearance       9       NaN             NaN          complex     pseudo
# 506   uneartile       9       NaN             NaN          complex     pseudo
# 507   uniforist       9       NaN             NaN          complex     pseudo
# 508   unifority       9       NaN             NaN          complex     pseudo
# 509   uniforize       9       NaN             NaN          complex     pseudo
# 510   unmistake       9       NaN             NaN          complex     pseudo
# 511   unmistate       9       NaN             NaN          complex     pseudo
# 512   unnaturse       9       NaN             NaN          complex     pseudo
# 513   vulgarist       9       NaN             NaN          complex     pseudo
# 514   vulgarize       9       NaN             NaN          complex     pseudo
# 515   wakeflate       9       NaN             NaN          complex     pseudo
# 516   weimbural       9       NaN             NaN          complex     pseudo
# 517   weimburse       9       NaN             NaN          complex     pseudo
# 518   weinforce       9       NaN             NaN          complex     pseudo
# 519   weinstake       9       NaN             NaN          complex     pseudo
# 520   weinstate       9       NaN             NaN          complex     pseudo
# 521   weirdnest       9       NaN             NaN          complex     pseudo
# 522   wiscreact       9       NaN             NaN          complex     pseudo
# 523   wiscreate       9       NaN             NaN          complex     pseudo
# 524   wiscredit       9       NaN             NaN          complex     pseudo
# 525   wisembark       9       NaN             NaN          complex     pseudo
# 526   wisembody       9       NaN             NaN          complex     pseudo
# 527   wisreport       9       NaN             NaN          complex     pseudo
# 528   witifully       9       NaN             NaN          complex     pseudo
# 529   woodority       9       NaN             NaN          complex     pseudo
# 530   woodorize       9       NaN             NaN          complex     pseudo
# 531   woodormly       9       NaN             NaN          complex     pseudo
# 532   yellowess       9       NaN             NaN          complex     pseudo
# 533     decycle       7       NaN             NaN          complex     pseudo
# 534     dislave       7       NaN             NaN          complex     pseudo
# 535     enslike       7       NaN             NaN          complex     pseudo
# 536     enspect       7       NaN             NaN          complex     pseudo
# 537     fatalue       7       NaN             NaN          complex     pseudo
# 538     fatcher       7       NaN             NaN          complex     pseudo
# 539     immover       7       NaN             NaN          complex     pseudo
# 540     nonsory       7       NaN             NaN          complex     pseudo
# 541     rearful       7       NaN             NaN          complex     pseudo
# 542     recoder       7       NaN             NaN          complex     pseudo
# 543     remoral       7       NaN             NaN          complex     pseudo
# 544     senstop       7       NaN             NaN          complex     pseudo
# 545     teactor       7       NaN             NaN          complex     pseudo
# 546     tensory       7       NaN             NaN          complex     pseudo
# 547     watally       7       NaN             NaN          complex     pseudo
# 548    dishaven       8       NaN             NaN          complex     pseudo
# 549    dishonal       8       NaN             NaN          complex     pseudo
# 550    egoisely       8       NaN             NaN          complex     pseudo
# 551    entanize       8       NaN             NaN          complex     pseudo
# 552    fourtive       8       NaN             NaN          complex     pseudo
# 553    overster       8       NaN             NaN          complex     pseudo
# 554    reustler       8       NaN             NaN          complex     pseudo
# 555    searless       8       NaN             NaN          complex     pseudo
# 556    seasonor       8       NaN             NaN          complex     pseudo
# 557    sprindly       8       NaN             NaN          complex     pseudo
# 558    teasonal       8       NaN             NaN          complex     pseudo
# 559    uninfort       8       NaN             NaN          complex     pseudo
# 560    unshonor       8       NaN             NaN          complex     pseudo
# 561    upholite       8       NaN             NaN          complex     pseudo
# 562    wrestful       8       NaN             NaN          complex     pseudo
# 563   clearally       9       NaN             NaN          complex     pseudo
# 564   deodorism       9       NaN             NaN          complex     pseudo
# 565   discreate       9       NaN             NaN          complex     pseudo
# 566   misembark       9       NaN             NaN          complex     pseudo
# 567   mishfully       9       NaN             NaN          complex     pseudo
# 568   overility       9       NaN             NaN          complex     pseudo
# 569   procreact       9       NaN             NaN          complex     pseudo
# 570   redersion       9       NaN             NaN          complex     pseudo
# 571   reimbural       9       NaN             NaN          complex     pseudo
# 572   remindful       9       NaN             NaN          complex     pseudo
# 573   tensenest       9       NaN             NaN          complex     pseudo
# 574   unifority       9       NaN             NaN          complex     pseudo
# 575   weinforce       9       NaN             NaN          complex     pseudo
# 576   witifully       9       NaN             NaN          complex     pseudo
# 577   woodorize       9       NaN             NaN          complex     pseudo
# 578     addreat       7       NaN             NaN           simple     pseudo
# 579     advange       7       NaN             NaN           simple     pseudo
# 580     advanna       7       NaN             NaN           simple     pseudo
# 581     afflity       7       NaN             NaN           simple     pseudo
# 582     ailence       7       NaN             NaN           simple     pseudo
# 583     aillage       7       NaN             NaN           simple     pseudo
# 584     airsute       7       NaN             NaN           simple     pseudo
# 585     allenue       7       NaN             NaN           simple     pseudo
# 586     alleron       7       NaN             NaN           simple     pseudo
# 587     amaland       7       NaN             NaN           simple     pseudo
# 588     amalanx       7       NaN             NaN           simple     pseudo
# 589     amalict       7       NaN             NaN           simple     pseudo
# 590     amallow       7       NaN             NaN           simple     pseudo
# ...
# 1404            NaN                               [W, ER1, N]
# 1405            NaN                          [W, OW1, D, OW0]
# 1406            NaN                               [W, AO1, R]
# 1407            NaN                          [W, AO1, R, IY0]
# 1408            NaN                          [W, OW1, Z, IY0]
# 1409            NaN                        [EY1, B, IY0, ER0]
# 1410            NaN                       [AE1, K, T, L, IY0]
# 1411            NaN                          [AE1, K, T, OY0]
# 1412            NaN                     [AH0, M, AO1, N, IY0]
# 1413            NaN                               [B, IY1, D]
# 1414            NaN                       [B, EH1, B, AH0, N]
# 1415            NaN                       [B, EH1, B, AH0, T]
# 1416            NaN                            [B, ER1, T, S]
# 1417            NaN                          [B, IY1, S, ER0]
# 1418            NaN                       [B, IY1, S, IY0, Z]
# 1419            NaN                       [B, EH1, T, IH0, T]
# 1420            NaN                          [B, EH1, T, ER0]
# 1421            NaN                         [B, L, AE1, K, T]
# 1422            NaN                       [B, L, UW1, L, AH0]
# 1423            NaN                          [B, OW1, L, ER0]
# 1424            NaN                          [B, OW1, Z, ER0]
# 1425            NaN                            [B, OW1, Z, S]
# 1426            NaN                             [D, EY1, ER0]
# 1427            NaN                          [D, EY1, M, ER0]
# 1428            NaN                               [D, AW1, Z]
# 1429            NaN                          [D, EY1, L, IY0]
# 1430            NaN                                  [IY1, W]
# 1431            NaN                             [IY1, L, ER0]
# 1432            NaN                               [IY1, L, Z]
# 1433            NaN                               [IY1, M, Z]
# 1434            NaN                               [ER1, T, S]
# 1435            NaN                          [IH1, R, AH0, T]
# 1436            NaN                             [IY1, T, IY0]
# 1437            NaN                                [OW1, ER0]
# 1438            NaN                          [Y, UW1, L, IY0]
# 1439            NaN                                [AY1, ER0]
# 1440            NaN                               [IY1, L, Z]
# 1441            NaN                          [EH0, N, EY1, D]
# 1442            NaN                       [EH1, N, T, W, IY0]
# 1443            NaN                          [EH1, N, T, OY0]
# 1444            NaN                          [EH1, N, Z, IY0]
# 1445            NaN                       [EH1, N, Z, IH0, T]
# 1446            NaN                            [F, L, EY1, D]
# 1447            NaN                         [F, L, AA1, R, Z]
# 1448            NaN                            [G, EY1, L, Z]
# 1449            NaN                          [G, AE1, L, AH0]
# 1450            NaN                          [G, AE1, M, IY0]
# 1451            NaN                       [G, AA1, R, L, AH0]
# 1452            NaN                         [HH, EH1, P, IY0]
# 1453            NaN                      [HH, EH1, R, AH0, L]
# 1454            NaN                           [HH, ER1, L, Z]
# 1455            NaN                         [HH, EH1, S, ER0]
# 1456            NaN                         [HH, IY1, T, ER0]
# 1457            NaN                         [HH, AH1, N, IY0]
# 1458            NaN                          [L, AO1, L, IY0]
# 1459            NaN                       [L, AY1, D, AH0, P]
# 1460            NaN                       [L, IH1, V, IH0, T]
# 1461            NaN                          [L, AO1, N, IY0]
# 1462            NaN                       [L, OW1, S, AH0, T]
# 1463            NaN                             [AA1, D, IY0]
# 1464            NaN                          [P, AE1, M, IY0]
# 1465            NaN                          [P, AE1, T, IY0]
# 1466            NaN                             [P, AW1, ER0]
# 1467            NaN                         [P, AE1, L, K, T]
# 1468            NaN                         [P, L, AE1, G, Z]
# 1469            NaN                         [P, L, AA1, R, Z]
# 1470            NaN                            [P, L, UW1, D]
# 1471            NaN                            [P, L, UW1, Z]
# 1472            NaN                               [R, EH1, D]
# 1473            NaN                       [R, EH1, B, AH0, G]
# 1474            NaN                          [R, EH1, F, IY0]
# 1475            NaN                       [R, EH1, F, IH0, P]
# 1476            NaN                       [R, EH1, R, L, IY0]
# 1477            NaN                          [R, IY1, Z, ER0]
# 1478            NaN                       [R, EH1, T, L, IY0]
# 1479            NaN                          [R, IY1, T, ER0]
# 1480            NaN                               [R, OY1, Z]
# 1481            NaN                              [R, AO1, NG]
# 1482            NaN                          [R, OW1, Z, ER0]
# 1483            NaN                              [SH, AY1, Z]
# 1484            NaN                            [S, K, AY1, D]
# 1485            NaN                       [S, K, IY1, W, EH0]
# 1486            NaN                       [S, K, AY1, L, IY0]
# 1487            NaN                          [S, AH1, N, ER0]
# 1488            NaN                       [AH0, N, AE1, K, T]
# 1489            NaN                          [AH0, N, EY1, D]
# 1490            NaN                      [Y, UW1, N, IH0, JH]
# 1491            NaN                    [Y, UW1, N, AH0, G, Z]
# 1492            NaN                       [AH0, N, D, IH1, T]
# 1493            NaN                      [AH0, N, JH, AO1, R]
# 1494            NaN                         [AH0, N, JH, OY1]
# 1495            NaN                       [AH1, N, T, L, AH0]
# 1496            NaN                          [AH1, N, Z, IY0]
# 1497            NaN                       [AH0, N, S, AY1, T]
# 1498            NaN                             [AH0, P, AY1]
# 1499            NaN                          [AH1, P, AH0, S]
# 1500            NaN                          [AH1, P, AH0, T]
# 1501            NaN                    [Y, UW1, Z, AE0, D, Z]
# 1502            NaN                    [Y, UW1, S, AE0, G, Z]
# 1503            NaN                       [Y, UW1, Z, ER0, Z]
# 1504            NaN                               [W, IY1, Z]
# 1505            NaN                       [W, EH1, B, AH0, T]
# 1506            NaN                          [W, EH1, T, ER0]
# 1507            NaN                          [W, AY1, V, ER0]
# 1508            NaN                       [W, IH1, V, IH0, T]
# 1509            NaN                       [AH0, B, R, AY1, K]
# 1510            NaN                       [AH0, B, R, UW1, T]
# 1511            NaN                       [EY1, B, R, AH0, S]
# 1512            NaN                       [AE1, K, R, OW0, D]
# 1513            NaN                  [AH0, K, R, OY1, IH0, K]
# 1514            NaN                       [AH0, K, R, UW1, T]
# 1515            NaN                          [AE1, L, OW0, N]
# 1516            NaN                   [AO1, ER0, AH0, L, IY0]
# 1517            NaN                    [AH0, W, AO1, R, T, S]
# 1518            NaN                          [B, ER0, IY1, D]
# 1519            NaN                    [B, EH1, R, AH0, L, Z]
# 1520            NaN                       [B, IH0, F, IH1, L]
# 1521            NaN                       [B, EH1, F, ER0, T]
# 1522            NaN               [B, EH1, F, Y, UW0, AH0, L]
# 1523            NaN                  [B, IH0, M, OW1, AH0, D]
# 1524            NaN                       [B, L, EY1, M, ER0]
# 1525            NaN                         [B, L, EY1, N, Z]
# 1526            NaN                       [B, L, OW1, L, IY0]
# 1527            NaN                      [B, R, AE1, N, T, S]
# 1528            NaN                         [B, R, AY1, M, Z]
# 1529            NaN                       [B, AY1, P, AH0, S]
# 1530            NaN                         [K, AW1, N, D, Z]
# 1531            NaN                      [K, R, IH1, N, T, S]
# 1532            NaN                         [K, R, AY1, T, S]
# 1533            NaN                         [D, IH1, R, D, Z]
# 1534            NaN                            [D, ER1, T, S]
# 1535            NaN                       [D, IH1, S, OW0, Z]
# 1536            NaN                          [IY1, Z, AH0, L]
# 1537            NaN                    [IH0, N, K, AA1, S, K]
# 1538            NaN                    [EH0, N, K, AE1, S, T]
# 1539            NaN                    [IH0, N, K, L, AE1, D]
# 1540            NaN                  [EH0, N, M, AA1, S, IY0]
# 1541            NaN                       [EH1, N, M, AH0, S]
# 1542            NaN                    [EH1, N, M, AH0, S, T]
# 1543            NaN                    [EH1, N, R, AH0, L, Z]
# 1544            NaN                       [EH0, N, T, UW1, T]
# 1545            NaN                 [EH1, K, S, P, AO2, R, M]
# 1546            NaN                    [EH1, K, S, P, ER0, Z]
# 1547            NaN                         [F, L, EY1, N, Z]
# 1548            NaN                      [F, L, AE1, N, T, S]
# 1549            NaN                      [HH, EH1, R, OW0, S]
# 1550            NaN                      [HH, OW1, T, ER0, Z]
# 1551            NaN                       [IY1, K, OW0, N, Z]
# 1552            NaN                    [IH0, M, P, AO1, R, M]
# 1553            NaN                       [IH1, N, S, ER0, Z]
# 1554            NaN                    [IH1, N, S, P, AE2, N]
# 1555            NaN                       [L, EY1, B, L, IY0]
# 1556            NaN                         [M, EY1, N, T, S]
# 1557            NaN                            [M, EY1, Z, D]
# 1558            NaN                    [M, IH0, S, AA1, R, M]
# 1559            NaN                    [S, IH0, S, B, AA1, R]
# 1560            NaN                    [M, IH1, S, T, IH0, L]
# 1561            NaN                  [OW1, P, IY0, AE2, K, S]
# 1562            NaN                       [AO0, R, EY1, N, Z]
# 1563            NaN                    [AO1, R, AH0, N, T, S]
# 1564            NaN                         [P, L, AE1, K, S]
# 1565            NaN                        [P, R, IH1, NG, Z]
# 1566            NaN                       [P, R, AY1, T, ER0]
# 1567            NaN                         [P, R, AY1, T, S]
# 1568            NaN                       [R, EH1, R, AH0, D]
# 1569            NaN                      [R, EH1, R, IH0, SH]
# 1570            NaN                         [R, AA1, R, M, Z]
# 1571            NaN                       [R, IY0, K, EY1, S]
# 1572            NaN                    [R, IY0, K, AE1, S, K]
# 1573            NaN                  [R, EH1, F, AH0, L, IY0]
# 1574            NaN                       [R, IY1, F, ER0, Z]
# 1575            NaN                       [R, IY0, F, UW1, L]
# 1576            NaN                    [R, IY0, F, Y, UW1, D]
# 1577            NaN                    [R, IY0, EH1, R, T, S]
# 1578            NaN                            [R, ER1, V, D]
# 1579            NaN                       [R, IY0, T, AA1, M]
# 1580            NaN                       [R, IY0, T, UW1, T]
# 1581            NaN                     [S, ER0, OW1, IH0, K]
# 1582            NaN                      [SH, AA1, R, L, IY0]
# 1583            NaN                       [S, L, UW1, D, IY0]
# 1584            NaN                    [S, N, AO1, R, L, IY0]
# 1585            NaN                         [S, AW1, N, T, S]
# 1586            NaN                    [S, P, EH1, N, L, IY0]
# 1587            NaN                       [T, R, AE1, L, IY0]
# 1588            NaN                         [T, R, EY1, N, Z]
# 1589            NaN                    [AH1, N, B, OW2, L, D]
# 1590            NaN                       [AH0, N, M, EY1, Z]
# 1591            NaN                      [AH0, N, M, EH1, SH]
# 1592            NaN                    [AH0, N, M, EH1, S, T]
# 1593            NaN                      [AH0, N, R, EH1, SH]
# 1594            NaN                      [AH1, N, R, IH0, CH]
# 1595            NaN                       [AH0, N, S, ER0, Z]
# 1596            NaN                      [AH0, P, HH, IY1, L]
# 1597            NaN                       [AH0, P, OW1, L, T]
# 1598            NaN                       [AH0, P, R, UW1, K]
# 1599            NaN                       [W, EH1, R, AH0, D]
# 1600            NaN                    [W, EH1, R, AH0, L, Z]
# 1601            NaN                       [W, EH1, R, L, IY0]
# 1602            NaN                         [W, AO1, R, M, Z]
# 1603            NaN                    [W, AO1, T, AH0, L, Z]
# 1604            NaN                       [W, EY1, T, L, IY0]
# 1605            NaN                         [W, UW1, N, T, S]
# 1606            NaN                            [R, AY1, M, Z]
# 1607            NaN                       [Y, IY1, D, L, IY0]
# 1608            NaN                         [Y, IH1, R, D, Z]
# 1609            NaN                            [AA1, R, N, Z]
# 1610            NaN                       [AE1, K, S, AH0, N]
# 1611            NaN                              [D, EH1, TH]
# 1612            NaN                             [IH1, R, IY0]
# 1613            NaN                              [G, EH1, TH]
# 1614            NaN                          [IH1, N, T, IY0]
# 1615            NaN                          [L, EY1, Z, IY0]
# 1616            NaN                          [AA1, K, S, ER0]
# 1617            NaN                  [OW0, N, IY1, T, AH0, T]
# 1618            NaN                               [P, AW1, N]
# 1619            NaN                               [R, UW1, Z]
# 1620            NaN                               [S, AO1, R]
# 1621            NaN                       [Y, UW1, S, AH0, N]
# 1622            NaN                          [W, AY1, AA0, R]
# 1623            NaN                          [W, OW1, Z, IY0]
# 1624            NaN                       [AE1, K, T, L, IY0]
# 1625            NaN                       [B, EH1, B, AH0, T]
# 1626            NaN                          [B, OW1, Z, ER0]
# 1627            NaN                               [ER1, T, S]
# 1628            NaN                          [EH1, N, T, OY0]
# 1629            NaN                           [HH, ER1, L, Z]
# 1630            NaN                          [L, AO1, N, IY0]
# 1631            NaN                          [P, AE1, M, IY0]
# 1632            NaN                         [P, AE1, L, K, T]
# 1633            NaN                               [R, EH1, D]
# 1634            NaN                       [R, EH1, B, AH0, G]
# 1635            NaN                      [Y, UW1, N, IH0, JH]
# 1636            NaN                         [AH0, N, JH, OY1]
# 1637            NaN                       [W, EH1, B, AH0, T]
# 1638            NaN                       [W, IH1, V, IH0, T]
# 1639            NaN                       [AH0, B, R, UW1, T]
# 1640            NaN               [B, EH1, F, Y, UW0, AH0, L]
# 1641            NaN                  [B, IH0, M, OW1, AH0, D]
# 1642            NaN                       [EH1, N, M, AH0, S]
# 1643            NaN                    [EH1, K, S, P, ER0, Z]
# 1644            NaN                    [M, IH0, S, AA1, R, M]
# 1645            NaN                        [P, R, IH1, NG, Z]
# 1646            NaN                       [R, IY0, T, AA1, M]
# 1647            NaN                     [S, ER0, OW1, IH0, K]
# 1648            NaN                    [S, P, EH1, N, L, IY0]
# 1649            NaN                      [AH1, N, R, IH0, CH]
# 1650            NaN                       [AH0, P, OW1, L, T]
# 1651            NaN                    [W, EH1, R, AH0, L, Z]
# 1652            NaN                       [W, EY1, T, L, IY0]
# 1653            NaN                         [Y, IH1, R, D, Z]

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
data['Part of Speech'] = data['Word'].apply(lambda x: nlp(x)[0].pos_)
data
# Out:
#            Word  Length Frequency  Zipf Frequency Morph Complexity Lexicality  \
# 0       bathmat       7       low            1.55          complex       real
# 1       decoder       7       low            2.84          complex       real
# 2       defiant       7       low            3.21          complex       real
# 3       padlock       7       low            2.68          complex       real
# 4       immoral       7       low            3.46          complex       real
# 5       nonstop       7       low            3.37          complex       real
# 6       parasol       7       low            2.63          complex       real
# 7       reactor       7       low            3.83          complex       real
# 8       recycle       7       low            3.35          complex       real
# 9       reenact       7       low            2.42          complex       real
# 10      reliant       7       low            3.41          complex       real
# 11      toaster       7       low            3.33          complex       real
# 12      upstage       7       low            2.35          complex       real
# 13      weirder       7       low            3.02          complex       real
# 14      weirdly       7       low            3.06          complex       real
# 15     alienate       8       low            3.03          complex       real
# 16     birdcage       8       low            2.45          complex       real
# 17     fourthly       8       low            2.08          complex       real
# 18     hopeless       8       low            3.71          complex       real
# 19     impolite       8       low            2.62          complex       real
# 20     scissors       8       low            3.58          complex       real
# 21     outsmart       8       low            2.67          complex       real
# 22     overcook       8       low            2.18          complex       real
# 23     necklace       8       low            3.85          complex       real
# 24     solvable       8       low            2.58          complex       real
# 25     curtains       8       low            3.66          complex       real
# 26     trustful       8       low            2.05          complex       real
# 27     unicycle       8       low            2.37          complex       real
# 28     popsicle       8       low            2.82          complex       real
# 29     suitcase       8       low            3.55          complex       real
# 30    adaptable       9       low            3.12          complex       real
# 31    blueberry       9       low            3.30          complex       real
# 32    cornbread       9       low            2.72          complex       real
# 33    disembark       9       low            2.68          complex       real
# 34    drumstick       9       low            2.36          complex       real
# 35    formality       9       low            3.15          complex       real
# 36    hamburger       9       low            3.45          complex       real
# 37    reinforce       9       low            3.68          complex       real
# 38    tattooist       9       low            1.99          complex       real
# 39    underline       9       low            2.98          complex       real
# 40    pineapple       9       low            3.58          complex       real
# 41    unnatural       9       low            3.48          complex       real
# 42    weirdness       9       low            2.92          complex       real
# 43    wishfully       9       low            1.44          complex       real
# 44    womanizer       9       low            2.61          complex       real
# 45      amphora       7       low            2.21           simple       real
# 46      stutter       7       low            2.95           simple       real
# 47      giraffe       7       low            3.32           simple       real
# 48      compass       7       low            3.74           simple       real
# 49      frisbee       7       low            2.96           simple       real
# 50      whistle       7       low            3.88           simple       real
# 51      javelin       7       low            2.90           simple       real
# 52      jugular       7       low            2.78           simple       real
# 53      legible       7       low            2.80           simple       real
# 54      liqueur       7       low            2.81           simple       real
# 55      penguin       7       low            3.78           simple       real
# 56      sapient       7       low            2.10           simple       real
# 57      satchel       7       low            2.90           simple       real
# 58      savanna       7       low            2.83           simple       real
# 59      whither       7       low            2.52           simple       real
# 60     cassette       8       low            3.40           simple       real
# 61     fumigate       8       low            1.87           simple       real
# 62     gargoyle       8       low            2.63           simple       real
# 63     instinct       8       low            3.86           simple       real
# 64     trombone       8       low            2.97           simple       real
# 65     umbrella       8       low            3.89           simple       real
# 66     mushroom       8       low            3.63           simple       real
# 67     hedgehog       8       low            3.25           simple       real
# 68     persuade       8       low            3.82           simple       real
# 69     scrabble       8       low            3.04           simple       real
# 70     skeleton       8       low            3.80           simple       real
# 71     stimulus       8       low            3.82           simple       real
# 72     kangaroo       8       low            3.50           simple       real
# 73     syndrome       8       low            4.23           simple       real
# 74     eggplant       8       low            3.01           simple       real
# 75    butterfly       9       low            3.93           simple       real
# 76    avalanche       9       low            3.48           simple       real
# 77    blaspheme       9       low            2.16           simple       real
# 78    boomerang       9       low            3.06           simple       real
# 79    boulevard       9       low            3.70           simple       real
# 80    catalogue       9       low            3.91           simple       real
# 81    chameleon       9       low            3.10           simple       real
# 82    champagne       9       low            3.90           simple       real
# 83    embarrass       9       low            3.41           simple       real
# 84    etiquette       9       low            3.40           simple       real
# 85    hurricane       9       low            4.10           simple       real
# 86    neighbour       9       low            3.69           simple       real
# 87    reservoir       9       low            3.90           simple       real
# 88    threshold       9       low            4.03           simple       real
# 89    versatile       9       low            3.66           simple       real
# 90         arty       4       low            2.99          complex       real
# 91         dewy       4       low            2.64          complex       real
# 92         gory       4       low            2.98          complex       real
# 93         hath       4       low            3.62          complex       real
# 94         hewn       4       low            2.67          complex       real
# 95         idly       4       low            2.93          complex       real
# 96         mugs       4       low            3.24          complex       real
# 97         oxen       4       low            2.90          complex       real
# 98         pods       4       low            3.45          complex       real
# 100        redo       4       low            3.19          complex       real
# 101        sows       4       low            2.59          complex       real
# 102        unto       4       low            3.96          complex       real
# 103        urns       4       low            2.71          complex       real
# 104        wiry       4       low            2.51          complex       real
# 105       befit       5       low            2.07          complex       real
# 106       combs       5       low            3.17          complex       real
# 107       debug       5       low            2.86          complex       real
# 108       enact       5       low            3.43          complex       real
# 109       ruler       5       low            3.84          complex       real
# 110       mixer       5       low            3.50          complex       real
# 111       odder       5       low            2.10          complex       real
# 112       paler       5       low            2.87          complex       real
# 113       renew       5       low            3.73          complex       real
# 114       repay       5       low            3.66          complex       real
# 115       reset       5       low            3.83          complex       real
# 116       shyly       5       low            2.42          complex       real
# 117       skier       5       low            3.20          complex       real
# 118       unzip       5       low            2.55          complex       real
# 119       wetly       5       low            1.41          complex       real
# 120      bowtie       6       low            2.40          complex       real
# 121      exhale       6       low            3.11          complex       real
# 122      heroic       6       low            3.84          complex       real
# 123      inhale       6       low            3.25          complex       real
# 124      pencil       6       low            3.95          complex       real
# 125      orally       6       low            3.12          complex       real
# 126      grapes       6       low            3.73          complex       real
# 127      faucet       6       low            3.07          complex       real
# 128      shears       6       low            2.90          complex       real
# 129      softly       6       low            3.77          complex       real
# 130      shells       6       low            3.93          complex       real
# 131      unreal       6       low            3.59          complex       real
# 132      uphill       6       low            3.38          complex       real
# 133      warmer       6       low            3.76          complex       real
# 134      yearly       6       low            3.88          complex       real
# 135        foot       4      high            4.87           simple       real
# 136        ally       4      high            4.10           simple       real
# 137        back       4      high            6.04           simple       real
# 138        iron       4      high            4.74           simple       real
# 139        dare       4      high            4.31           simple       real
# 140        dumb       4      high            4.54           simple       real
# 141        bear       4      high            4.71           simple       real
# 142        goat       4      high            4.02           simple       real
# 143        hack       4      high            4.05           simple       real
# 144        tank       4      high            4.57           simple       real
# 145        mild       4      high            4.11           simple       real
# 146        belt       4      high            4.42           simple       real
# 147        rain       4      high            4.71           simple       real
# 148        shot       4      high            5.22           simple       real
# 149        west       4      high            5.29           simple       real
# 150       fence       5      high            4.21           simple       real
# 151       truck       5      high            4.64           simple       real
# 152       drone       5      high            4.00           simple       real
# 153       house       5      high            5.71           simple       real
# 154       large       5      high            5.39           simple       real
# 155       least       5      high            5.44           simple       real
# 156       money       5      high            5.64           simple       real
# 157       piano       5      high            4.31           simple       real
# 158       swing       5      high            4.34           simple       real
# 159       radio       5      high            5.01           simple       real
# 160       sword       5      high            4.37           simple       real
# 161       phone       5      high            5.30           simple       real
# 162       quite       5      high            5.29           simple       real
# 163       knife       5      high            4.41           simple       real
# 164       salad       5      high            4.15           simple       real
# 165      wallet       6      high            4.15           simple       real
# 166      engine       6      high            4.84           simple       real
# 167      enough       6      high            5.54           simple       real
# 168      family       6      high            5.66           simple       real
# 169      guitar       6      high            4.48           simple       real
# 170      govern       6      high            3.67           simple       real
# 171      little       6      high            5.75           simple       real
# 172      jersey       6      high            4.66           simple       real
# 173      cherry       6      high            4.18           simple       real
# 174      school       6      high            5.71           simple       real
# 175      simple       6      high            5.08           simple       real
# 176      strong       6      high            5.22           simple       real
# 177      camera       6      high            4.87           simple       real
# 178      target       6      high            4.82           simple       real
# 179      window       6      high            4.80           simple       real
# 180     captain       7      high            4.89           simple       real
# 181     despite       7      high            5.00           simple       real
# 182     gravity       7      high            4.21           simple       real
# 183     horizon       7      high            4.07           simple       real
# 184     inspire       7      high            4.00           simple       real
# 185     journey       7      high            4.65           simple       real
# 186     kitchen       7      high            4.65           simple       real
# 187     library       7      high            4.86           simple       real
# 188     natural       7      high            5.11           simple       real
# 189     rainbow       7      high            4.07           simple       real
# 190     shallow       7      high            4.04           simple       real
# 191     strange       7      high            4.64           simple       real
# 192     vaccine       7      high            4.00           simple       real
# 193     village       7      high            4.82           simple       real
# 194     missile       7      high            4.14           simple       real
# 195    absolute       8      high            4.54           simple       real
# 196   aluminium       8      high            3.73           simple       real
# 197    calendar       8      high            4.30           simple       real
# 198    elephant       8      high            4.08           simple       real
# 199    gorgeous       8      high            4.35           simple       real
# 200    hospital       8      high            5.07           simple       real
# 201    medicine       8      high            4.73           simple       real
# 202    mountain       8      high            4.73           simple       real
# 203    remember       8      high            5.38           simple       real
# 204    sandwich       8      high            4.13           simple       real
# 205    shoulder       8      high            4.50           simple       real
# 206    straight       8      high            5.04           simple       real
# 207    together       8      high            5.46           simple       real
# 208    treasure       8      high            4.17           simple       real
# 209    exercise       8      high            4.68           simple       real
# 210   algorithm       9      high            4.02           simple       real
# 211   aluminium       9      high            3.73           simple       real
# 212   architect       9      high            4.08           simple       real
# 213   automatic       9      high            4.36           simple       real
# 214   challenge       9      high            4.88           simple       real
# 215   character       9      high            5.11           simple       real
# 216   chocolate       9      high            4.49           simple       real
# 217   desperate       9      high            4.32           simple       real
# 218   emergency       9      high            4.72           simple       real
# 219   establish       9      high            4.46           simple       real
# 220   hurricane       9      high            4.10           simple       real
# 221   immediate       9      high            4.52           simple       real
# 222   peninsula       9      high            4.03           simple       real
# 223   satellite       9      high            4.33           simple       real
# 224   surrender       9      high            4.09           simple       real
# 225        ajar       4       low            2.57           simple       real
# 226        balk       4       low            2.72           simple       real
# 227        bark       4       low            3.85           simple       real
# 228        rake       4       low            3.38           simple       real
# 229        frog       4       low            3.89           simple       real
# 230        glee       4       low            3.49           simple       real
# 231        heft       4       low            2.75           simple       real
# 232        hymn       4       low            3.61           simple       real
# 233        lore       4       low            3.55           simple       real
# 234        sock       4       low            3.61           simple       real
# 235        peel       4       low            3.80           simple       real
# 236        quay       4       low            3.26           simple       real
# 237        quip       4       low            2.67           simple       real
# 238        wane       4       low            2.83           simple       real
# 239        zest       4       low            3.19           simple       real
# 240       acorn       5       low            3.08           simple       real
# 241       broom       5       low            3.42           simple       real
# 242       scarf       5       low            3.68           simple       real
# 243       glove       5       low            3.73           simple       real
# 244       easel       5       low            2.68           simple       real
# 245       hoist       5       low            3.12           simple       real
# 246       leery       5       low            2.58           simple       real
# 247       lithe       5       low            2.48           simple       real
# 248       camel       5       low            3.64           simple       real
# 249       mirth       5       low            2.62           simple       real
# 250       quill       5       low            3.11           simple       real
# 251       scour       5       low            2.97           simple       real
# 252       clown       5       low            3.93           simple       real
# 253       vault       5       low            3.90           simple       real
# 254       yacht       5       low            3.82           simple       real
# 255      arcane       6       low            2.99           simple       real
# 256      beetle       6       low            3.53           simple       real
# 257      bullet       6       low            4.24           simple       real
# 258      castle       6       low            4.45           simple       real
# 259      citrus       6       low            3.58           simple       real
# 260      frivol       6       low            0.00           simple       real
# 261      frugal       6       low            3.11           simple       real
# 262      mingle       6       low            3.21           simple       real
# 263      needle       6       low            3.98           simple       real
# 264      peddle       6       low            2.76           simple       real
# 265      puzzle       6       low            3.96           simple       real
# 266      quiver       6       low            2.84           simple       real
# 267      ramble       6       low            2.85           simple       real
# 268      writhe       6       low            2.24           simple       real
# 269      kettle       6       low            3.54           simple       real
# 270     anxiety       7      high            4.45          complex       real
# 271     briefly       7      high            4.22          complex       real
# 272     careful       7      high            4.59          complex       real
# 273     coastal       7      high            4.19          complex       real
# 274     enabled       7      high            4.11          complex       real
# 275     endless       7      high            4.18          complex       real
# 276     farmers       7      high            4.43          complex       real
# 277     glasses       7      high            4.34          complex       real
# 278     genetic       7      high            4.34          complex       real
# 279     matches       7      high            4.59          complex       real
# 280     medical       7      high            5.16          complex       real
# 281     mixture       7      high            4.18          complex       real
# 282     officer       7      high            5.03          complex       real
# 283     society       7      high            5.17          complex       real
# 284     studied       7      high            4.49          complex       real
# 285    affected       8      high            4.64          complex       real
# 286    alliance       8      high            4.40          complex       real
# 287    clinical       8      high            4.51          complex       real
# 288    computer       8      high            4.97          complex       real
# 289    disagree       8      high            4.09          complex       real
# 290    dramatic       8      high            4.41          complex       real
# 291    football       8      high            5.11          complex       real
# 292    homeless       8      high            4.26          complex       real
# 293    included       8      high            5.03          complex       real
# 294    mentally       8      high            4.20          complex       real
# 295    northern       8      high            4.85          complex       real
# 296    pictures       8      high            4.92          complex       real
# 297    students       8      high            5.25          complex       real
# 298    ultimate       8      high            4.53          complex       real
# 299    warriors       8      high            4.30          complex       real
# 300   allegedly       9      high            4.06          complex       real
# 301   confirmed       9      high            4.67          complex       real
# 302   criminals       9      high            4.15          complex       real
# 303   currently       9      high            5.08          complex       real
# 304   departure       9      high            4.22          complex       real
# 305   disappear       9      high            4.09          complex       real
# 306   engineers       9      high            4.41          complex       real
# 307   important       9      high            5.44          complex       real
# 308   overnight       9      high            4.19          complex       real
# 309   political       9      high            5.29          complex       real
# 310   pollution       9      high            4.20          complex       real
# 311   receiving       9      high            4.59          complex       real
# 312   scientist       9      high            4.21          complex       real
# 313   seriously       9      high            4.94          complex       real
# 314   wonderful       9      high            4.85          complex       real
# 315        axis       4      high            4.02          complex       real
# 316        cuts       4      high            4.42          complex       real
# 317        dies       4      high            4.41          complex       real
# 318        easy       4      high            5.29          complex       real
# 319        into       4      high            6.11          complex       real
# 320        jury       4      high            4.49          complex       real
# 321        lets       4      high            4.51          complex       real
# 322        liar       4      high            4.02          complex       real
# 323        nary       4      high            2.59          complex       real
# 324        sexy       4      high            4.42          complex       real
# 325        torn       4      high            4.08          complex       real
# 326        unit       4      high            4.95          complex       real
# 327        user       4      high            4.69          complex       real
# 328        wins       4      high            4.70          complex       real
# 329        worn       4      high            4.26          complex       real
# 330       actor       5      high            4.65          complex       real
# 331       among       5      high            5.31          complex       real
# 332      bloody       5      high            4.28          complex       real
# 333       blues       5      high            4.34          complex       real
# 334       boats       5      high            4.25          complex       real
# 335       bones       5      high            4.32          complex       real
# 336       daily       5      high            5.07          complex       real
# 337       early       5      high            5.43          complex       real
# 338       enjoy       5      high            5.09          complex       real
# 339       flags       5      high            4.09          complex       real
# 340       rings       5      high            4.33          complex       real
# 341       hurts       5      high            4.30          complex       real
# 342       lived       5      high            4.88          complex       real
# 343       birds       5      high            4.60          complex       real
# 344       stars       5      high            4.86          complex       real
# 345      across       6      high            5.25          complex       real
# 346      brains       6      high            4.07          complex       real
# 347      deaths       6      high            4.53          complex       real
# 348      flames       6      high            4.03          complex       real
# 349      hearts       6      high            4.44          complex       real
# 350      hotels       6      high            4.22          complex       real
# 351      iconic       6      high            4.13          complex       real
# 352      planes       6      high            4.16          complex       real
# 353      rarely       6      high            4.42          complex       real
# 354      stones       6      high            4.31          complex       real
# 355       sunny       6      high            4.07          complex       real
# 356      trains       6      high            4.27          complex       real
# 357      helmet       6      high            4.02          complex       real
# 358      wounds       6      high            4.07          complex       real
# 359      writes       6      high            4.36          complex       real
# 360     decycle       7       NaN            0.00          complex     pseudo
# 361     devably       7       NaN            0.00          complex     pseudo
# 362     devally       7       NaN            0.00          complex     pseudo
# 363     dislave       7       NaN            0.00          complex     pseudo
# 364     enslike       7       NaN            0.00          complex     pseudo
# 365     enspect       7       NaN            0.00          complex     pseudo
# 366     fatalue       7       NaN            0.00          complex     pseudo
# 367     fatcher       7       NaN            0.00          complex     pseudo
# 368     immover       7       NaN            0.00          complex     pseudo
# 369     inslave       7       NaN            0.00          complex     pseudo
# 370     inslike       7       NaN            0.00          complex     pseudo
# 371     modalue       7       NaN            0.00          complex     pseudo
# 372     movally       7       NaN            0.00          complex     pseudo
# 373     movalue       7       NaN            0.00          complex     pseudo
# 374     nonsory       7       NaN            0.00          complex     pseudo
# 375     nonstor       7       NaN            0.00          complex     pseudo
# 376     reactop       7       NaN            0.00          complex     pseudo
# 377     rearful       7       NaN            0.00          complex     pseudo
# 378     recoder       7       NaN            0.00          complex     pseudo
# 379     remoral       7       NaN            0.00          complex     pseudo
# 380     rensory       7       NaN            0.00          complex     pseudo
# 381     renstop       7       NaN            0.00          complex     pseudo
# 382     renstor       7       NaN            0.00          complex     pseudo
# 383     senewal       7       NaN            0.00          complex     pseudo
# 384     senstop       7       NaN            0.00          complex     pseudo
# 385     senstor       7       NaN            0.00          complex     pseudo
# 386     teactop       7       NaN            0.00          complex     pseudo
# 387     teactor       7       NaN            0.00          complex     pseudo
# 388     tenewal       7       NaN            0.00          complex     pseudo
# 389     tensory       7       NaN            0.00          complex     pseudo
# 390     tenstop       7       NaN            0.00          complex     pseudo
# 391     tenstor       7       NaN            0.00          complex     pseudo
# 392     watally       7       NaN            0.00          complex     pseudo
# 393     watalue       7       NaN            0.00          complex     pseudo
# 394    dishaven       8       NaN            0.00          complex     pseudo
# 395    dishonal       8       NaN            0.00          complex     pseudo
# 396    egoisely       8       NaN            0.00          complex     pseudo
# 397    egoistep       8       NaN            0.00          complex     pseudo
# 398    egoister       8       NaN            0.00          complex     pseudo
# 399    entanize       8       NaN            0.00          complex     pseudo
# 400    fourness       8       NaN            0.00          complex     pseudo
# 401    fourtive       8       NaN            0.00          complex     pseudo
# 402    impolder       8       NaN            0.00          complex     pseudo
# 403    overster       8       NaN            0.00          complex     pseudo
# 404    overstic       8       NaN            0.00          complex     pseudo
# 405    reimporm       8       NaN            0.00          complex     pseudo
# 406    reustful       8       NaN            0.00          complex     pseudo
# 407    reustler       8       NaN            0.00          complex     pseudo
# 408    searless       8       NaN            0.00          complex     pseudo
# 409    seasonor       8       NaN            0.00          complex     pseudo
# 410    sourtive       8       NaN            0.00          complex     pseudo
# 411    sprictep       8       NaN            0.00          complex     pseudo
# 412    spricter       8       NaN            0.00          complex     pseudo
# 413    sprindly       8       NaN            0.00          complex     pseudo
# 414    sprintep       8       NaN            0.00          complex     pseudo
# 415    strictep       8       NaN            0.00          complex     pseudo
# 416    strindly       8       NaN            0.00          complex     pseudo
# 417    strintep       8       NaN            0.00          complex     pseudo
# 418    strinter       8       NaN            0.00          complex     pseudo
# 419    teasonal       8       NaN            0.00          complex     pseudo
# 420    teasonor       8       NaN            0.00          complex     pseudo
# 421    trusable       8       NaN            0.00          complex     pseudo
# 422    trustler       8       NaN            0.00          complex     pseudo
# 423    uninfort       8       NaN            0.00          complex     pseudo
# 424    unkintep       8       NaN            0.00          complex     pseudo
# 425    unkinter       8       NaN            0.00          complex     pseudo
# 426    unshonal       8       NaN            0.00          complex     pseudo
# 427    unshonor       8       NaN            0.00          complex     pseudo
# 428    unwistep       8       NaN            0.00          complex     pseudo
# 429    unwister       8       NaN            0.00          complex     pseudo
# 430    unwistic       8       NaN            0.00          complex     pseudo
# 431    upholite       8       NaN            0.00          complex     pseudo
# 432    womangle       8       NaN            0.00          complex     pseudo
# 433    wrestful       8       NaN            0.00          complex     pseudo
# 434   clearally       9       NaN            0.00          complex     pseudo
# 435   cleartile       9       NaN            0.00          complex     pseudo
# 436   deodeness       9       NaN            0.00          complex     pseudo
# 437   deodenest       9       NaN            0.00          complex     pseudo
# 438   deodorism       9       NaN            0.00          complex     pseudo
# 439   deodorist       9       NaN            0.00          complex     pseudo
# 440   deoutsell       9       NaN            0.00          complex     pseudo
# 441   discreach       9       NaN            0.00          complex     pseudo
# 442   discreact       9       NaN            0.00          complex     pseudo
# 443   discreate       9       NaN            0.00          complex     pseudo
# 444   dishfully       9       NaN            0.00          complex     pseudo
# 445   disreport       9       NaN            0.00          complex     pseudo
# 446   distfully       9       NaN            0.00          complex     pseudo
# 447   formaline       9       NaN            0.00          complex     pseudo
# 448   immerlity       9       NaN            0.00          complex     pseudo
# 449   immerlize       9       NaN            0.00          complex     pseudo
# 450   immerpass       9       NaN            0.00          complex     pseudo
# 451   immersold       9       NaN            0.00          complex     pseudo
# 452   immertile       9       NaN            0.00          complex     pseudo
# 453   immorance       9       NaN            0.00          complex     pseudo
# 454   inferline       9       NaN            0.00          complex     pseudo
# 455   inferlity       9       NaN            0.00          complex     pseudo
# 456   inferpass       9       NaN            0.00          complex     pseudo
# 457   infersion       9       NaN            0.00          complex     pseudo
# 458   infersold       9       NaN            0.00          complex     pseudo
# 459   miscreact       9       NaN            0.00          complex     pseudo
# 460   misembark       9       NaN            0.00          complex     pseudo
# 461   misembody       9       NaN            0.00          complex     pseudo
# 462   mishfully       9       NaN            0.00          complex     pseudo
# 463   mistfully       9       NaN            0.00          complex     pseudo
# 464   normaline       9       NaN            0.00          complex     pseudo
# 465   overiline       9       NaN            0.00          complex     pseudo
# 466   overility       9       NaN            0.00          complex     pseudo
# 467   overilize       9       NaN            0.00          complex     pseudo
# 468   overreate       9       NaN            0.00          complex     pseudo
# 469   overredit       9       NaN            0.00          complex     pseudo
# 470   pitlessly       9       NaN            0.00          complex     pseudo
# 471   procreach       9       NaN            0.00          complex     pseudo
# 472   procreact       9       NaN            0.00          complex     pseudo
# 473   procredit       9       NaN            0.00          complex     pseudo
# 474   redefully       9       NaN            0.00          complex     pseudo
# 475   rederline       9       NaN            0.00          complex     pseudo
# 476   rederlity       9       NaN            0.00          complex     pseudo
# 477   rederlize       9       NaN            0.00          complex     pseudo
# 478   rederpass       9       NaN            0.00          complex     pseudo
# 479   redersion       9       NaN            0.00          complex     pseudo
# 480   redersold       9       NaN            0.00          complex     pseudo
# 481   redertile       9       NaN            0.00          complex     pseudo
# 482   reimbural       9       NaN            0.00          complex     pseudo
# 483   reinstake       9       NaN            0.00          complex     pseudo
# 484   reirdness       9       NaN            0.00          complex     pseudo
# 485   remindful       9       NaN            0.00          complex     pseudo
# 486   remistate       9       NaN            0.00          complex     pseudo
# 487   reodeness       9       NaN            0.00          complex     pseudo
# 488   reodenest       9       NaN            0.00          complex     pseudo
# 489   reodorism       9       NaN            0.00          complex     pseudo
# 490   reodorize       9       NaN            0.00          complex     pseudo
# 491   reodormly       9       NaN            0.00          complex     pseudo
# 492   steriline       9       NaN            0.00          complex     pseudo
# 493   sterreach       9       NaN            0.00          complex     pseudo
# 494   sterreact       9       NaN            0.00          complex     pseudo
# 495   sterreate       9       NaN            0.00          complex     pseudo
# 496   sterredit       9       NaN            0.00          complex     pseudo
# 497   tattooism       9       NaN            0.00          complex     pseudo
# 498   tensenest       9       NaN            0.00          complex     pseudo
# 499   tuneflate       9       NaN            0.00          complex     pseudo
# 500   undeflate       9       NaN            0.00          complex     pseudo
# 501   undefully       9       NaN            0.00          complex     pseudo
# 502   underlity       9       NaN            0.00          complex     pseudo
# 503   undersion       9       NaN            0.00          complex     pseudo
# 504   undertile       9       NaN            0.00          complex     pseudo
# 505   unearally       9       NaN            0.00          complex     pseudo
# 506   unearance       9       NaN            0.00          complex     pseudo
# 507   uneartile       9       NaN            0.00          complex     pseudo
# 508   uniforist       9       NaN            0.00          complex     pseudo
# 509   unifority       9       NaN            0.00          complex     pseudo
# 510   uniforize       9       NaN            0.00          complex     pseudo
# 511   unmistake       9       NaN            0.00          complex     pseudo
# 512   unmistate       9       NaN            0.00          complex     pseudo
# 513   unnaturse       9       NaN            0.00          complex     pseudo
# 514   vulgarist       9       NaN            0.00          complex     pseudo
# 515   vulgarize       9       NaN            0.00          complex     pseudo
# 516   wakeflate       9       NaN            0.00          complex     pseudo
# 517   weimbural       9       NaN            0.00          complex     pseudo
# 518   weimburse       9       NaN            0.00          complex     pseudo
# 519   weinforce       9       NaN            0.00          complex     pseudo
# 520   weinstake       9       NaN            0.00          complex     pseudo
# 521   weinstate       9       NaN            0.00          complex     pseudo
# 522   weirdnest       9       NaN            0.00          complex     pseudo
# 523   wiscreact       9       NaN            0.00          complex     pseudo
# 524   wiscreate       9       NaN            0.00          complex     pseudo
# 525   wiscredit       9       NaN            0.00          complex     pseudo
# 526   wisembark       9       NaN            0.00          complex     pseudo
# 527   wisembody       9       NaN            0.00          complex     pseudo
# 528   wisreport       9       NaN            0.00          complex     pseudo
# 529   witifully       9       NaN            0.00          complex     pseudo
# 530   woodority       9       NaN            0.00          complex     pseudo
# 531   woodorize       9       NaN            0.00          complex     pseudo
# 532   woodormly       9       NaN            0.00          complex     pseudo
# 533   yellowess       9       NaN            0.00          complex     pseudo
# 534     decycle       7       NaN            0.00          complex     pseudo
# 535     dislave       7       NaN            0.00          complex     pseudo
# 536     enslike       7       NaN            0.00          complex     pseudo
# 537     enspect       7       NaN            0.00          complex     pseudo
# 538     fatalue       7       NaN            0.00          complex     pseudo
# 539     fatcher       7       NaN            0.00          complex     pseudo
# 540     immover       7       NaN            0.00          complex     pseudo
# 541     nonsory       7       NaN            0.00          complex     pseudo
# 542     rearful       7       NaN            0.00          complex     pseudo
# 543     recoder       7       NaN            0.00          complex     pseudo
# 544     remoral       7       NaN            0.00          complex     pseudo
# 545     senstop       7       NaN            0.00          complex     pseudo
# 546     teactor       7       NaN            0.00          complex     pseudo
# 547     tensory       7       NaN            0.00          complex     pseudo
# 548     watally       7       NaN            0.00          complex     pseudo
# 549    dishaven       8       NaN            0.00          complex     pseudo
# 550    dishonal       8       NaN            0.00          complex     pseudo
# 551    egoisely       8       NaN            0.00          complex     pseudo
# 552    entanize       8       NaN            0.00          complex     pseudo
# 553    fourtive       8       NaN            0.00          complex     pseudo
# 554    overster       8       NaN            0.00          complex     pseudo
# 555    reustler       8       NaN            0.00          complex     pseudo
# 556    searless       8       NaN            0.00          complex     pseudo
# 557    seasonor       8       NaN            0.00          complex     pseudo
# 558    sprindly       8       NaN            0.00          complex     pseudo
# 559    teasonal       8       NaN            0.00          complex     pseudo
# 560    uninfort       8       NaN            0.00          complex     pseudo
# 561    unshonor       8       NaN            0.00          complex     pseudo
# 562    upholite       8       NaN            0.00          complex     pseudo
# 563    wrestful       8       NaN            0.00          complex     pseudo
# 564   clearally       9       NaN            0.00          complex     pseudo
# 565   deodorism       9       NaN            0.00          complex     pseudo
# 566   discreate       9       NaN            0.00          complex     pseudo
# 567   misembark       9       NaN            0.00          complex     pseudo
# 568   mishfully       9       NaN            0.00          complex     pseudo
# 569   overility       9       NaN            0.00          complex     pseudo
# 570   procreact       9       NaN            0.00          complex     pseudo
# 571   redersion       9       NaN            0.00          complex     pseudo
# 572   reimbural       9       NaN            0.00          complex     pseudo
# 573   remindful       9       NaN            0.00          complex     pseudo
# 574   tensenest       9       NaN            0.00          complex     pseudo
# 575   unifority       9       NaN            0.00          complex     pseudo
# 576   weinforce       9       NaN            0.00          complex     pseudo
# 577   witifully       9       NaN            0.00          complex     pseudo
# 578   woodorize       9       NaN            0.00          complex     pseudo
# 579     addreat       7       NaN            0.00           simple     pseudo
# 580     advange       7       NaN            0.00           simple     pseudo
# 581     advanna       7       NaN            0.00           simple     pseudo
# 582     afflity       7       NaN            0.00           simple     pseudo
# 583     ailence       7       NaN            0.00           simple     pseudo
# 584     aillage       7       NaN            0.00           simple     pseudo
# 585     airsute       7       NaN            0.00           simple     pseudo
# 586     allenue       7       NaN            0.00           simple     pseudo
# 587     alleron       7       NaN            0.00           simple     pseudo
# 588     amaland       7       NaN            0.00           simple     pseudo
# 589     amalanx       7       NaN            0.00           simple     pseudo
# 590     amalict       7       NaN            0.00           simple     pseudo
# 591     amallow       7       NaN            0.00           simple     pseudo
# ...
# 928            VERB
# 929           PROPN
# 930            VERB
# 931            NOUN
# 932           PROPN
# 933            NOUN
# 934            NOUN
# 935             ADV
# 936             ADV
# 937           PROPN
# 938            VERB
# 939           PROPN
# 940            VERB
# 941            VERB
# 942            VERB
# 943           PROPN
# 944            NOUN
# 945           PROPN
# 946           PROPN
# 947            VERB
# 948           PROPN
# 949            VERB
# 950           PROPN
# 951            NOUN
# 952            NOUN
# 953            NOUN
# 954            NOUN
# 955            NOUN
# 956            NOUN
# 957           PROPN
# 958            VERB
# 959            VERB
# 960            VERB
# 961            NOUN
# 962            NOUN
# 963            NOUN
# 964           PROPN
# 965           PROPN
# 966           PROPN
# 967           PROPN
# 968            NOUN
# 969            NOUN
# 970            NOUN
# 971            NOUN
# 972           PROPN
# 973            NOUN
# 974            VERB
# 975            VERB
# 976            NOUN
# 977            NOUN
# 978            NOUN
# 979           PROPN
# 980            NOUN
# 981            NOUN
# 982           PROPN
# 983           PROPN
# 984           PROPN
# 985            NOUN
# 986           PROPN
# 987            NOUN
# 988             ADV
# 989           PROPN
# 990           PROPN
# 991           PROPN
# 992            NOUN
# 993            VERB
# 994            VERB
# 995            NOUN
# 996           PROPN
# 997           PROPN
# 998            VERB
# 999            VERB
# 1000           VERB
# 1001           VERB
# 1002           VERB
# 1003          PROPN
# 1004          PROPN
# 1005           NOUN
# 1006           NOUN
# 1007           NOUN
# 1008            ADJ
# 1009           NOUN
# 1010          PROPN
# 1011           VERB
# 1012           VERB
# 1013           VERB
# 1014           VERB
# 1015           VERB
# 1016           NOUN
# 1017          PROPN
# 1018          PROPN
# 1019          PROPN
# 1020           NOUN
# 1021           NOUN
# 1022          PROPN
# 1023           NOUN
# 1024           NOUN
# 1025            ADV
# 1026           NOUN
# 1027           NOUN
# 1028           NOUN
# 1029           VERB
# 1030          PROPN
# 1031          PROPN
# 1032          PROPN
# 1033          PROPN
# 1034           NOUN
# 1035          PROPN
# 1036           VERB
# 1037            ADJ
# 1038           VERB
# 1039           NOUN
# 1040            ADV
# 1041          PROPN
# 1042           VERB
# 1043           NOUN
# 1044           NOUN
# 1045           NOUN
# 1046            ADJ
# 1047           NOUN
# 1048           NOUN
# 1049          PROPN
# 1050          PROPN
# 1051           NOUN
# 1052           NOUN
# 1053          PROPN
# 1054           VERB
# 1055          PROPN
# 1056          PROPN
# 1057          PROPN
# 1058          PROPN
# 1059           NOUN
# 1060           VERB
# 1061           NOUN
# 1062           NOUN
# 1063          PROPN
# 1064           VERB
# 1065           NOUN
# 1066          PROPN
# 1067           VERB
# 1068           NOUN
# 1069           VERB
# 1070          PROPN
# 1071          PROPN
# 1072           NOUN
# 1073           NOUN
# 1074           VERB
# 1075           NOUN
# 1076            ADJ
# 1077           NOUN
# 1078           VERB
# 1079           NOUN
# 1080            ADJ
# 1081          PROPN
# 1082           NOUN
# 1083          PROPN
# 1084           VERB
# 1085          PROPN
# 1086           NOUN
# 1087           NOUN
# 1088          PROPN
# 1089           NOUN
# 1090           NOUN
# 1091           NOUN
# 1092           NOUN
# 1093           VERB
# 1094           VERB
# 1095           NOUN
# 1096          PROPN
# 1097           NOUN
# 1098           VERB
# 1099           NOUN
# 1100           VERB
# 1101            ADV
# 1102           NOUN
# 1103           VERB
# 1104           NOUN
# 1105          PROPN
# 1106            ADJ
# 1107           VERB
# 1108            ADJ
# 1109            ADV
# 1110           NOUN
# 1111           VERB
# 1112           VERB
# 1113          PROPN
# 1114           NOUN
# 1115           NOUN
# 1116           NOUN
# 1117           NOUN
# 1118          PROPN
# 1119          PROPN
# 1120          PROPN
# 1121          PROPN
# 1122          PROPN
# 1123           NOUN
# 1124           NOUN
# 1125            ADJ
# 1126           VERB
# 1127           NOUN
# 1128          PROPN
# 1129          PROPN
# 1130           VERB
# 1131          PROPN
# 1132           VERB
# 1133           VERB
# 1134          PROPN
# 1135          PROPN
# 1136           NOUN
# 1137           VERB
# 1138           NOUN
# 1139           NOUN
# 1140           NOUN
# 1141           NOUN
# 1142           NOUN
# 1143           NOUN
# 1144          PROPN
# 1145           NOUN
# 1146            ADV
# 1147           NOUN
# 1148           VERB
# 1149           VERB
# 1150           NOUN
# 1151            ADJ
# 1152           NOUN
# 1153            ADP
# 1154            ADJ
# 1155           VERB
# 1156          PROPN
# 1157           VERB
# 1158           NOUN
# 1159           NOUN
# 1160           NOUN
# 1161           NOUN
# 1162           NOUN
# 1163           NOUN
# 1164            ADJ
# 1165           VERB
# 1166          PROPN
# 1167          PROPN
# 1168          PROPN
# 1169           VERB
# 1170          PROPN
# 1171           NOUN
# 1172          PROPN
# 1173           NOUN
# 1174           NOUN
# 1175           NOUN
# 1176          PROPN
# 1177          PROPN
# 1178          PROPN
# 1179           NOUN
# 1180            ADJ
# 1181          PROPN
# 1182          PROPN
# 1183          PROPN
# 1184           NOUN
# 1185           VERB
# 1186          PROPN
# 1187          PROPN
# 1188           VERB
# 1189          PROPN
# 1190            ADJ
# 1191           VERB
# 1192          PROPN
# 1193           VERB
# 1194          PROPN
# 1195          PROPN
# 1196           VERB
# 1197            ADV
# 1198           NOUN
# 1199           NOUN
# 1200          PROPN
# 1201            ADJ
# 1202           NOUN
# 1203           VERB
# 1204           INTJ
# 1205           NOUN
# 1206           NOUN
# 1207          PROPN
# 1208           VERB
# 1209           VERB
# 1210           NOUN
# 1211           NOUN
# 1212           NOUN
# 1213           NOUN
# 1214          PROPN
# 1215           NOUN
# 1216          PROPN
# 1217           NOUN
# 1218           VERB
# 1219           NOUN
# 1220            ADV
# 1221          PROPN
# 1222          PROPN
# 1223           NOUN
# 1224           NOUN
# 1225           NOUN
# 1226           NOUN
# 1227           VERB
# 1228          PROPN
# 1229           VERB
# 1230           NOUN
# 1231           VERB
# 1232           NOUN
# 1233            ADJ
# 1234           VERB
# 1235           NOUN
# 1236           NOUN
# 1237           VERB
# 1238           VERB
# 1239           VERB
# 1240            ADV
# 1241            ADJ
# 1242          PROPN
# 1243            ADV
# 1244           VERB
# 1245          PROPN
# 1246           NOUN
# 1247           NOUN
# 1248            ADP
# 1249            ADJ
# 1250           NOUN
# 1251           NOUN
# 1252           VERB
# 1253           VERB
# 1254           VERB
# 1255          PROPN
# 1256          PROPN
# 1257           NOUN
# 1258           NOUN
# 1259          PROPN
# 1260           NOUN
# 1261          PROPN
# 1262          PROPN
# 1263           NOUN
# 1264          PROPN
# 1265           NOUN
# 1266            ADV
# 1267           NOUN
# 1268           NOUN
# 1269          PROPN
# 1270           NOUN
# 1271           NOUN
# 1272          PROPN
# 1273          PROPN
# 1274           VERB
# 1275          PROPN
# 1276           VERB
# 1277           VERB
# 1278           NOUN
# 1279           NOUN
# 1280            ADV
# 1281           VERB
# 1282          PROPN
# 1283           VERB
# 1284          PROPN
# 1285          PROPN
# 1286           NOUN
# 1287          PROPN
# 1288           VERB
# 1289           VERB
# 1290           NOUN
# 1291          PROPN
# 1292           NOUN
# 1293           NOUN
# 1294          PROPN
# 1295           VERB
# 1296           VERB
# 1297           VERB
# 1298           NOUN
# 1299            ADV
# 1300            ADJ
# 1301           VERB
# 1302           NOUN
# 1303            ADJ
# 1304           VERB
# 1305           NOUN
# 1306          PROPN
# 1307           NOUN
# 1308           NOUN
# 1309           NOUN
# 1310           NOUN
# 1311           NOUN
# 1312           NOUN
# 1313           NOUN
# 1314          PROPN
# 1315           NOUN
# 1316           NOUN
# 1317            ADJ
# 1318           VERB
# 1319           NOUN
# 1320           VERB
# 1321          PROPN
# 1322           NOUN
# 1323           VERB
# 1324           NOUN
# 1325          PROPN
# 1326           VERB
# 1327           VERB
# 1328           NOUN
# 1329           VERB
# 1330           NOUN
# 1331          PROPN
# 1332           NOUN
# 1333           NOUN
# 1334          PROPN
# 1335           VERB
# 1336           NOUN
# 1337           NOUN
# 1338          PROPN
# 1339           VERB
# 1340           NOUN
# 1341            ADJ
# 1342           VERB
# 1343          PROPN
# 1344          PROPN
# 1345            ADV
# 1346           VERB
# 1347           NOUN
# 1348          PROPN
# 1349          PROPN
# 1350           NOUN
# 1351           NOUN
# 1352           NOUN
# 1353           NOUN
# 1354          PROPN
# 1355          PROPN
# 1356          PROPN
# 1357          PROPN
# 1358           NOUN
# 1359           NOUN
# 1360           NOUN
# 1361            ADV
# 1362           NOUN
# 1363            ADJ
# 1364           NOUN
# 1365           NOUN
# 1366          PROPN
# 1367           NOUN
# 1368          PROPN
# 1369           NOUN
# 1370          PROPN
# 1371          PROPN
# 1372          PROPN
# 1373          PROPN
# 1374           NOUN
# 1375            ADJ
# 1376           NOUN
# 1377           NOUN
# 1378           NOUN
# 1379          PROPN
# 1380            ADJ
# 1381          PROPN
# 1382           NOUN
# 1383           NOUN
# 1384           VERB
# 1385           NOUN
# 1386           NOUN
# 1387           NOUN
# 1388           VERB
# 1389          PROPN
# 1390           VERB
# 1391          PROPN
# 1392           VERB
# 1393           NOUN
# 1394           VERB
# 1395           VERB
# 1396            ADJ
# 1397           NOUN
# 1398          PROPN
# 1399            ADJ
# 1400           NOUN
# 1401           NOUN
# 1402           VERB
# 1403           NOUN
# 1404          PROPN
# 1405           NOUN
# 1406           NOUN
# 1407          PROPN
# 1408            ADJ
# 1409           NOUN
# 1410            ADV
# 1411            ADV
# 1412           VERB
# 1413          PROPN
# 1414           NOUN
# 1415           VERB
# 1416            ADV
# 1417           NOUN
# 1418          PROPN
# 1419           NOUN
# 1420           NOUN
# 1421           NOUN
# 1422           VERB
# 1423           NOUN
# 1424          PROPN
# 1425           VERB
# 1426          PROPN
# 1427            ADJ
# 1428           NOUN
# 1429           VERB
# 1430           VERB
# 1431           NOUN
# 1432          PROPN
# 1433           NOUN
# 1434           NOUN
# 1435           VERB
# 1436           NOUN
# 1437          PROPN
# 1438          PROPN
# 1439            ADV
# 1440           NOUN
# 1441           NOUN
# 1442           VERB
# 1443          PROPN
# 1444           VERB
# 1445          PROPN
# 1446           NOUN
# 1447           VERB
# 1448           NOUN
# 1449           VERB
# 1450          PROPN
# 1451           VERB
# 1452           NOUN
# 1453          PROPN
# 1454           NOUN
# 1455           NOUN
# 1456            ADV
# 1457           NOUN
# 1458           VERB
# 1459            ADV
# 1460          PROPN
# 1461           NOUN
# 1462           NOUN
# 1463          PROPN
# 1464          PROPN
# 1465           VERB
# 1466          PROPN
# 1467           NOUN
# 1468           NOUN
# 1469           NOUN
# 1470           NOUN
# 1471           VERB
# 1472           NOUN
# 1473           NOUN
# 1474           NOUN
# 1475          PROPN
# 1476          PROPN
# 1477            ADV
# 1478           NOUN
# 1479            ADV
# 1480           NOUN
# 1481           VERB
# 1482          PROPN
# 1483          PROPN
# 1484           NOUN
# 1485           VERB
# 1486           VERB
# 1487            ADV
# 1488           NOUN
# 1489           VERB
# 1490           NOUN
# 1491           VERB
# 1492           NOUN
# 1493           NOUN
# 1494           NOUN
# 1495           VERB
# 1496            ADV
# 1497          PROPN
# 1498            ADJ
# 1499           VERB
# 1500           VERB
# 1501            ADJ
# 1502           NOUN
# 1503           NOUN
# 1504           NOUN
# 1505           NOUN
# 1506           NOUN
# 1507           NOUN
# 1508           NOUN
# 1509           NOUN
# 1510            ADJ
# 1511            ADV
# 1512           NOUN
# 1513           VERB
# 1514            ADJ
# 1515           VERB
# 1516          PROPN
# 1517            ADV
# 1518           NOUN
# 1519          PROPN
# 1520           NOUN
# 1521           NOUN
# 1522           NOUN
# 1523           VERB
# 1524           NOUN
# 1525           NOUN
# 1526           NOUN
# 1527            ADV
# 1528           NOUN
# 1529           VERB
# 1530           NOUN
# 1531           NOUN
# 1532           NOUN
# 1533           NOUN
# 1534           NOUN
# 1535           NOUN
# 1536           VERB
# 1537           VERB
# 1538           VERB
# 1539            ADJ
# 1540           VERB
# 1541           NOUN
# 1542            ADJ
# 1543            ADJ
# 1544           NOUN
# 1545           NOUN
# 1546           NOUN
# 1547           NOUN
# 1548           VERB
# 1549           NOUN
# 1550           NOUN
# 1551           NOUN
# 1552           NOUN
# 1553           NOUN
# 1554           NOUN
# 1555           VERB
# 1556            ADV
# 1557           NOUN
# 1558           VERB
# 1559           NOUN
# 1560          PROPN
# 1561           VERB
# 1562           NOUN
# 1563           NOUN
# 1564           VERB
# 1565           NOUN
# 1566           NOUN
# 1567           NOUN
# 1568           VERB
# 1569           VERB
# 1570            ADJ
# 1571           VERB
# 1572           VERB
# 1573          PROPN
# 1574            ADV
# 1575           NOUN
# 1576          PROPN
# 1577           VERB
# 1578            ADV
# 1579           VERB
# 1580           VERB
# 1581           VERB
# 1582           VERB
# 1583            ADV
# 1584           NOUN
# 1585            ADV
# 1586           NOUN
# 1587            ADV
# 1588            ADV
# 1589           NOUN
# 1590           NOUN
# 1591           NOUN
# 1592            ADJ
# 1593            ADV
# 1594            ADJ
# 1595          PROPN
# 1596           NOUN
# 1597           NOUN
# 1598            ADJ
# 1599            ADJ
# 1600            ADV
# 1601           VERB
# 1602            ADV
# 1603           NOUN
# 1604           NOUN
# 1605            ADV
# 1606           NOUN
# 1607           NOUN
# 1608            ADV
# 1609            ADV
# 1610           NOUN
# 1611           NOUN
# 1612          PROPN
# 1613           NOUN
# 1614          PROPN
# 1615           NOUN
# 1616          PROPN
# 1617           NOUN
# 1618           NOUN
# 1619          PROPN
# 1620           NOUN
# 1621           VERB
# 1622           VERB
# 1623           NOUN
# 1624           NOUN
# 1625            ADV
# 1626            ADV
# 1627           VERB
# 1628           VERB
# 1629           VERB
# 1630           NOUN
# 1631           NOUN
# 1632           VERB
# 1633           NOUN
# 1634           NOUN
# 1635           NOUN
# 1636           VERB
# 1637           VERB
# 1638           NOUN
# 1639           NOUN
# 1640            ADV
# 1641           VERB
# 1642           NOUN
# 1643            ADJ
# 1644           NOUN
# 1645           NOUN
# 1646           NOUN
# 1647           VERB
# 1648           VERB
# 1649            ADV
# 1650          PROPN
# 1651            ADJ
# 1652           VERB
# 1653            ADV
# 1654            ADV

# %%
from morphemes import Morphemes
m = Morphemes("./morphemes_data")

def get_morphological_data(word):
    parse = m.parse(word)

    if parse["status"] == "NOT_FOUND":
        return [], [], [], [], 1, "0-1-0"
    
    tree = parse["tree"]

    prefixes = []
    roots = []
    root_freqs = []
    suffixes = []

    for node in tree:
        if node["type"] == "prefix":
            prefixes.append(node["text"])
        
        elif "children" in node:
            for child in node["children"]:
                if child["type"] == "root":
                    roots.append(child["text"])
                    root_freqs.append(zipf_frequency(child["text"], 'en'))
        else:
            suffixes.append(node["text"])

    count = parse["morpheme_count"]
    structure = f"{len(prefixes)}-{len(roots)}-{len(suffixes)}"

    return prefixes, roots, root_freqs, suffixes, count, structure

columns = ["Prefixes", "Roots", "Root Frequencies", "Suffixes", "Morpheme Count", "Morpheme Structure"]
data[columns] = data['Word'].apply(lambda word: pd.Series(get_morphological_data(word)))
data

# %%
from g2p_en import G2p

g2p = G2p()
data["Phonemes"] = data["Word"].apply(lambda x: g2p(x))
data
