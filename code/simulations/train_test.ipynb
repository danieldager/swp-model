# %%
from Phonemes import Phonemes
from utils import seed_everything

seed_everything()
P = Phonemes()

# %%
from train_repetition import train_repetition

params = {
    'n_epochs': 10,
    'h_size': 4,
    'n_layers': 2,
    'dropout': 0.1,
    'l_rate': 0.001
}

train_repetition(P, params)

# %%
from test_repetition import test_repetition

model_name = "e10_h4_l2_d0.1_r0.001"

dfrs = test_repetition(P, model_name)
# Out:
# Using MPS device
# Testing epoch 1_1...
# Testing epoch 1_2...
# Testing epoch 1_3...
# Testing epoch 1_4...
# Testing epoch 1_5...
# Testing epoch 1_6...
# Testing epoch 1_7...
# Testing epoch 1_8...
# Testing epoch 1_9...
# Testing epoch 1_10...
# Testing epoch 2...
# Testing epoch 3...
# Testing epoch 4...
# Testing epoch 5...
# Testing epoch 6...
# Testing epoch 7...
# Testing epoch 8...
# Testing epoch 9...
# Testing epoch 10...

# %%
import pandas as pd
pd.set_option('display.max_rows', 2000)
# sort test data by Zipf frequency
P.test_data.sort_values(by='Zipf Frequency', inplace=True)
P.test_data
# Out:
#           Word   Size  Length Frequency  Zipf Frequency Morphology Lexicality  \
# 29       wetly  short       5       low            1.41    complex       real
# 43   wishfully   long       9       low            1.44    complex       real
# 0      bathmat   long       7       low            1.55    complex       real
# 16    fumigate   long       8       low            1.87     simple       real
# 38   tattooist   long       9       low            1.99    complex       real
# 26    trustful   long       8       low            2.05    complex       real
# 15       befit  short       5       low            2.07    complex       real
# 17    fourthly   long       8       low            2.08    complex       real
# 21       odder  short       5       low            2.10    complex       real
# 11     sapient   long       7       low            2.10     simple       real
# 32   blaspheme   long       9       low            2.16     simple       real
# 22    overcook   long       8       low            2.18    complex       real
# 0      amphora   long       7       low            2.21     simple       real
# 43      writhe  short       6       low            2.24     simple       real
# 12     upstage   long       7       low            2.35    complex       real
# 34   drumstick   long       9       low            2.36    complex       real
# 27    unicycle   long       8       low            2.37    complex       real
# 30      bowtie  short       6       low            2.40    complex       real
# 26       shyly  short       5       low            2.42    complex       real
# 9      reenact   long       7       low            2.42    complex       real
# 16    birdcage   long       8       low            2.45    complex       real
# 22       lithe  short       5       low            2.48     simple       real
# 14        wiry  short       4       low            2.51    complex       real
# 14     whither   long       7       low            2.52     simple       real
# 28       unzip  short       5       low            2.55    complex       real
# 0         ajar  short       4       low            2.57     simple       real
# 21       leery  short       5       low            2.58     simple       real
# 24    solvable   long       8       low            2.58    complex       real
# 11        sows  short       4       low            2.59    complex       real
# 8         nary  short       4      high            2.59    complex       real
# 44   womanizer   long       9       low            2.61    complex       real
# 19    impolite   long       8       low            2.62    complex       real
# 24       mirth  short       5       low            2.62     simple       real
# 6      parasol   long       7       low            2.63    complex       real
# 17    gargoyle   long       8       low            2.63     simple       real
# 1         dewy  short       4       low            2.64    complex       real
# 12        quip  short       4       low            2.67     simple       real
# 4         hewn  short       4       low            2.67    complex       real
# 21    outsmart   long       8       low            2.67    complex       real
# 33   disembark   long       9       low            2.68    complex       real
# 19       easel  short       5       low            2.68     simple       real
# 3      padlock   long       7       low            2.68    complex       real
# 13        urns  short       4       low            2.71    complex       real
# 32   cornbread   long       9       low            2.72    complex       real
# 1         balk  short       4       low            2.72     simple       real
# 6         heft  short       4       low            2.75     simple       real
# 39      peddle  short       6       low            2.76     simple       real
# 7      jugular   long       7       low            2.78     simple       real
# 8      legible   long       7       low            2.80     simple       real
# 9      liqueur   long       7       low            2.81     simple       real
# 28    popsicle   long       8       low            2.82    complex       real
# 13        wane  short       4       low            2.83     simple       real
# 13     savanna   long       7       low            2.83     simple       real
# 41      quiver  short       6       low            2.84     simple       real
# 1      decoder   long       7       low            2.84    complex       real
# 42      ramble  short       6       low            2.85     simple       real
# 17       debug  short       5       low            2.86    complex       real
# 22       paler  short       5       low            2.87    complex       real
# 7         oxen  short       4       low            2.90    complex       real
# 12     satchel   long       7       low            2.90     simple       real
# 6      javelin   long       7       low            2.90     simple       real
# 38      shears  short       6       low            2.90    complex       real
# 42   weirdness   long       9       low            2.92    complex       real
# 5         idly  short       4       low            2.93    complex       real
# 35      trifle  short       6       low            2.93     simple       real
# 1      stutter   long       7       low            2.95     simple       real
# 4      frisbee   long       7       low            2.96     simple       real
# 26       scour  short       5       low            2.97     simple       real
# 19    trombone   long       8       low            2.97     simple       real
# 2         gory  short       4       low            2.98    complex       real
# 39   underline   long       9       low            2.98    complex       real
# 30      arcane  short       6       low            2.99     simple       real
# 0         arty  short       4       low            2.99    complex       real
# 29    eggplant   long       8       low            3.01     simple       real
# 13     weirder   long       7       low            3.02    complex       real
# 15    alienate   long       8       low            3.03    complex       real
# 24    scrabble   long       8       low            3.04     simple       real
# 14     weirdly   long       7       low            3.06    complex       real
# 33   boomerang   long       9       low            3.06     simple       real
# 37      faucet  short       6       low            3.07    complex       real
# 15       acorn  short       5       low            3.08     simple       real
# 36   chameleon   long       9       low            3.10     simple       real
# 31      exhale  short       6       low            3.11    complex       real
# 25       quill  short       5       low            3.11     simple       real
# 36      frugal  short       6       low            3.11     simple       real
# 35      orally  short       6       low            3.12    complex       real
# 30   adaptable   long       9       low            3.12    complex       real
# 20       hoist  short       5       low            3.12     simple       real
# 35   formality   long       9       low            3.15    complex       real
# 16       combs  short       5       low            3.17    complex       real
# 10        redo  short       4       low            3.19    complex       real
# 14        zest  short       4       low            3.19     simple       real
# 27       skier  short       5       low            3.20    complex       real
# 2      defiant   long       7       low            3.21    complex       real
# 37      mingle  short       6       low            3.21     simple       real
# 6         mugs  short       4       low            3.24    complex       real
# 22    hedgehog   long       8       low            3.25     simple       real
# 33      inhale  short       6       low            3.25    complex       real
# 11        quay  short       4       low            3.26     simple       real
# 31   blueberry   long       9       low            3.30    complex       real
# 2      giraffe   long       7       low            3.32     simple       real
# 11     toaster   long       7       low            3.33    complex       real
# 8      recycle   long       7       low            3.35    complex       real
# 5      nonstop   long       7       low            3.37    complex       real
# 3         rake  short       4       low            3.38     simple       real
# 42      uphill  short       6       low            3.38    complex       real
# 39   etiquette   long       9       low            3.40     simple       real
# 15    cassette   long       8       low            3.40     simple       real
# 38   embarrass   long       9       low            3.41     simple       real
# 10     reliant   long       7       low            3.41    complex       real
# 16       broom  short       5       low            3.42     simple       real
# 18       enact  short       5       low            3.43    complex       real
# 8         pods  short       4       low            3.45    complex       real
# 36   hamburger   long       9       low            3.45    complex       real
# 4      immoral   long       7       low            3.46    complex       real
# 41   unnatural   long       9       low            3.48    complex       real
# 31   avalanche   long       9       low            3.48     simple       real
# 5         glee  short       4       low            3.49     simple       real
# 27    kangaroo   long       8       low            3.50     simple       real
# 20       mixer  short       5       low            3.50    complex       real
# 31      beetle  short       6       low            3.53     simple       real
# 44      kettle  short       6       low            3.54     simple       real
# 8         lore  short       4       low            3.55     simple       real
# 29    suitcase   long       8       low            3.55    complex       real
# 40   pineapple   long       9       low            3.58    complex       real
# 20    scissors   long       8       low            3.58    complex       real
# 34      citrus  short       6       low            3.58     simple       real
# 41      unreal  short       6       low            3.59    complex       real
# 9         sock  short       4       low            3.61     simple       real
# 7         hymn  short       4       low            3.61     simple       real
# 3         hath  short       4       low            3.62    complex       real
# 21    mushroom   long       8       low            3.63     simple       real
# 23       camel  short       5       low            3.64     simple       real
# 24       repay  short       5       low            3.66    complex       real
# 44   versatile   long       9       low            3.66     simple       real
# 25    curtains   long       8       low            3.66    complex       real
# 35      govern  short       6      high            3.67     simple       real
# 37   reinforce   long       9       low            3.68    complex       real
# 17       scarf  short       5       low            3.68     simple       real
# 41   neighbour   long       9       low            3.69     simple       real
# 34   boulevard   long       9       low            3.70     simple       real
# 18    hopeless   long       8       low            3.71    complex       real
# 31   aluminium   long       9      high            3.73     simple       real
# 16   aluminium   long       8      high            3.73     simple       real
# 18       glove  short       5       low            3.73     simple       real
# 36      grapes  short       6       low            3.73    complex       real
# 23       renew  short       5       low            3.73    complex       real
# 3      compass   long       7       low            3.74     simple       real
# 43      warmer  short       6       low            3.76    complex       real
# 39      softly  short       6       low            3.77    complex       real
# 10     penguin   long       7       low            3.78     simple       real
# 25    skeleton   long       8       low            3.80     simple       real
# 10        peel  short       4       low            3.80     simple       real
# 29       yacht  short       5       low            3.82     simple       real
# 23    persuade   long       8       low            3.82     simple       real
# 26    stimulus   long       8       low            3.82     simple       real
# 7      reactor   long       7       low            3.83    complex       real
# 25       reset  short       5       low            3.83    complex       real
# 19       ruler  short       5       low            3.84    complex       real
# 32      heroic  short       6       low            3.84    complex       real
# 23    necklace   long       8       low            3.85    complex       real
# 2         bark  short       4       low            3.85     simple       real
# 18    instinct   long       8       low            3.86     simple       real
# 44      yearly  short       6       low            3.88    complex       real
# 5      whistle   long       7       low            3.88     simple       real
# 20    umbrella   long       8       low            3.89     simple       real
# 4         frog  short       4       low            3.89     simple       real
# 37   champagne   long       9       low            3.90     simple       real
# 28       vault  short       5       low            3.90     simple       real
# 42   reservoir   long       9       low            3.90     simple       real
# 35   catalogue   long       9       low            3.91     simple       real
# 30   butterfly   long       9       low            3.93     simple       real
# 40      shells  short       6       low            3.93    complex       real
# 27       clown  short       5       low            3.93     simple       real
# 34      pencil  short       6       low            3.95    complex       real
# 40      puzzle  short       6       low            3.96     simple       real
# 12        unto  short       4       low            3.96    complex       real
# 38      needle  short       6       low            3.98     simple       real
# 4      inspire   long       7      high            4.00     simple       real
# 17       drone  short       5      high            4.00     simple       real
# 12     vaccine   long       7      high            4.00     simple       real
# 7         goat  short       4      high            4.02     simple       real
# 0         axis  short       4      high            4.02    complex       real
# 7         liar  short       4      high            4.02    complex       real
# 42      helmet  short       6      high            4.02    complex       real
# 30   algorithm   long       9      high            4.02     simple       real
# 43   threshold   long       9       low            4.03     simple       real
# 42   peninsula   long       9      high            4.03     simple       real
# 33      flames  short       6      high            4.03    complex       real
# 10     shallow   long       7      high            4.04     simple       real
# 8         hack  short       4      high            4.05     simple       real
# 30   allegedly   long       9      high            4.06    complex       real
# 9      rainbow   long       7      high            4.07     simple       real
# 3      horizon   long       7      high            4.07     simple       real
# 40       sunny  short       6      high            4.07    complex       real
# 31      brains  short       6      high            4.07    complex       real
# 43      wounds  short       6      high            4.07    complex       real
# 18    elephant   long       8      high            4.08     simple       real
# 32   architect   long       9      high            4.08     simple       real
# 10        torn  short       4      high            4.08    complex       real
# 24       flags  short       5      high            4.09    complex       real
# 19    disagree   long       8      high            4.09    complex       real
# 35   disappear   long       9      high            4.09    complex       real
# 44   surrender   long       9      high            4.09     simple       real
# 40   hurricane   long       9       low            4.10     simple       real
# 1         ally  short       4      high            4.10     simple       real
# 40   hurricane   long       9      high            4.10     simple       real
# 10        mild  short       4      high            4.11     simple       real
# 4      enabled   long       7      high            4.11    complex       real
# 24    sandwich   long       8      high            4.13     simple       real
# 36      iconic  short       6      high            4.13    complex       real
# 14     missile   long       7      high            4.14     simple       real
# 32   criminals   long       9      high            4.15    complex       real
# 29       salad  short       5      high            4.15     simple       real
# 30      wallet  short       6      high            4.15     simple       real
# 37      planes  short       6      high            4.16    complex       real
# 28    treasure   long       8      high            4.17     simple       real
# 11     mixture   long       7      high            4.18    complex       real
# 5      endless   long       7      high            4.18    complex       real
# 38      cherry  short       6      high            4.18     simple       real
# 3      coastal   long       7      high            4.19    complex       real
# 38   overnight   long       9      high            4.19    complex       real
# 24    mentally   long       8      high            4.20    complex       real
# 40   pollution   long       9      high            4.20    complex       real
# 2      gravity   long       7      high            4.21     simple       real
# 42   scientist   long       9      high            4.21    complex       real
# 15       fence  short       5      high            4.21     simple       real
# 1      briefly   long       7      high            4.22    complex       real
# 34   departure   long       9      high            4.22    complex       real
# 35      hotels  short       6      high            4.22    complex       real
# 28    syndrome   long       8       low            4.23     simple       real
# 32      bullet  short       6       low            4.24     simple       real
# 19       boats  short       5      high            4.25    complex       real
# 22    homeless   long       8      high            4.26    complex       real
# 14        worn  short       4      high            4.26    complex       real
# 41      trains  short       6      high            4.27    complex       real
# 17      bloody  short       5      high            4.28    complex       real
# 26       hurts  short       5      high            4.30    complex       real
# 29    warriors   long       8      high            4.30    complex       real
# 17    calendar   long       8      high            4.30     simple       real
# 22       piano  short       5      high            4.31     simple       real
# 4         dare  short       4      high            4.31     simple       real
# 39      stones  short       6      high            4.31    complex       real
# 37   desperate   long       9      high            4.32     simple       real
# 20       bones  short       5      high            4.32    complex       real
# 25       rings  short       5      high            4.33    complex       real
# 43   satellite   long       9      high            4.33     simple       real
# 23       swing  short       5      high            4.34     simple       real
# 18       blues  short       5      high            4.34    complex       real
# 8      genetic   long       7      high            4.34    complex       real
# 7      glasses   long       7      high            4.34    complex       real
# 19    gorgeous   long       8      high            4.35     simple       real
# 44      writes  short       6      high            4.36    complex       real
# 33   automatic   long       9      high            4.36     simple       real
# 25       sword  short       5      high            4.37     simple       real
# 16    alliance   long       8      high            4.40    complex       real
# 36   engineers   long       9      high            4.41    complex       real
# 28       knife  short       5      high            4.41     simple       real
# 2         dies  short       4      high            4.41    complex       real
# 20    dramatic   long       8      high            4.41    complex       real
# 38      rarely  short       6      high            4.42    complex       real
# 11        belt  short       4      high            4.42     simple       real
# 9         sexy  short       4      high            4.42    complex       real
# 1         cuts  short       4      high            4.42    complex       real
# 6      farmers   long       7      high            4.43    complex       real
# 34      hearts  short       6      high            4.44    complex       real
# 33      castle  short       6       low            4.45     simple       real
# 0      anxiety   long       7      high            4.45    complex       real
# 39   establish   long       9      high            4.46     simple       real
# 34      guitar  short       6      high            4.48     simple       real
# 5         jury  short       4      high            4.49    complex       real
# 36   chocolate   long       9      high            4.49     simple       real
# 14     studied   long       7      high            4.49    complex       real
# 25    shoulder   long       8      high            4.50     simple       real
# 6         lets  short       4      high            4.51    complex       real
# 17    clinical   long       8      high            4.51    complex       real
# 41   immediate   long       9      high            4.52     simple       real
# 28    ultimate   long       8      high            4.53    complex       real
# 32      deaths  short       6      high            4.53    complex       real
# 15    absolute   long       8      high            4.54     simple       real
# 5         dumb  short       4      high            4.54     simple       real
# 9         tank  short       4      high            4.57     simple       real
# 41   receiving   long       9      high            4.59    complex       real
# 9      matches   long       7      high            4.59    complex       real
# 2      careful   long       7      high            4.59    complex       real
# 28       birds  short       5      high            4.60    complex       real
# 15    affected   long       8      high            4.64    complex       real
# 16       truck  short       5      high            4.64     simple       real
# 11     strange   long       7      high            4.64     simple       real
# 15       actor  short       5      high            4.65    complex       real
# 5      journey   long       7      high            4.65     simple       real
# 6      kitchen   long       7      high            4.65     simple       real
# 37      jersey  short       6      high            4.66     simple       real
# 31   confirmed   long       9      high            4.67    complex       real
# 29    exercise   long       8      high            4.68     simple       real
# 12        user  short       4      high            4.69    complex       real
# 13        wins  short       4      high            4.70    complex       real
# 6         bear  short       4      high            4.71     simple       real
# 12        rain  short       4      high            4.71     simple       real
# 38   emergency   long       9      high            4.72     simple       real
# 21    medicine   long       8      high            4.73     simple       real
# 22    mountain   long       8      high            4.73     simple       real
# 3         iron  short       4      high            4.74     simple       real
# 44      window  short       6      high            4.80     simple       real
# 13     village   long       7      high            4.82     simple       real
# 43      target  short       6      high            4.82     simple       real
# 31      engine  short       6      high            4.84     simple       real
# 25    northern   long       8      high            4.85    complex       real
# 44   wonderful   long       9      high            4.85    complex       real
# 29       stars  short       5      high            4.86    complex       real
# 7      library   long       7      high            4.86     simple       real
# 42      camera  short       6      high            4.87     simple       real
# 0         foot  short       4      high            4.87     simple       real
# 27       lived  short       5      high            4.88    complex       real
# 34   challenge   long       9      high            4.88     simple       real
# 0      captain   long       7      high            4.89     simple       real
# 26    pictures   long       8      high            4.92    complex       real
# 43   seriously   long       9      high            4.94    complex       real
# 11        unit  short       4      high            4.95    complex       real
# 18    computer   long       8      high            4.97    complex       real
# 1      despite   long       7      high            5.00     simple       real
# 24       radio  short       5      high            5.01     simple       real
# 12     officer   long       7      high            5.03    complex       real
# 23    included   long       8      high            5.03    complex       real
# 26    straight   long       8      high            5.04     simple       real
# 21       daily  short       5      high            5.07    complex       real
# 20    hospital   long       8      high            5.07     simple       real
# 33   currently   long       9      high            5.08    complex       real
# 40      simple  short       6      high            5.08     simple       real
# 23       enjoy  short       5      high            5.09    complex       real
# 8      natural   long       7      high            5.11     simple       real
# 35   character   long       9      high            5.11     simple       real
# 21    football   long       8      high            5.11    complex       real
# 10     medical   long       7      high            5.16    complex       real
# 13     society   long       7      high            5.17    complex       real
# 13        shot  short       4      high            5.22     simple       real
# 41      strong  short       6      high            5.22     simple       real
# 30      across  short       6      high            5.25    complex       real
# 27    students   long       8      high            5.25    complex       real
# 27       quite  short       5      high            5.29     simple       real
# 14        west  short       4      high            5.29     simple       real
# 39   political   long       9      high            5.29    complex       real
# 3         easy  short       4      high            5.29    complex       real
# 26       phone  short       5      high            5.30     simple       real
# 16       among  short       5      high            5.31    complex       real
# 23    remember   long       8      high            5.38     simple       real
# 19       large  short       5      high            5.39     simple       real
# 22       early  short       5      high            5.43    complex       real
# 37   important   long       9      high            5.44    complex       real
# 20       least  short       5      high            5.44     simple       real
# 27    together   long       8      high            5.46     simple       real
# 32      enough  short       6      high            5.54     simple       real
# 21       money  short       5      high            5.64     simple       real
# 33      family  short       6      high            5.66     simple       real
# 18       house  short       5      high            5.71     simple       real
# 39      school  short       6      high            5.71     simple       real
# 36      little  short       6      high            5.75     simple       real
# 2         back  short       4      high            6.04     simple       real
# 4         into  short       4      high            6.11    complex       real
# 0      decycle   long       7       NaN             NaN    complex     pseudo
# 1      devably   long       7       NaN             NaN    complex     pseudo
# 2      devally   long       7       NaN             NaN    complex     pseudo
# 3      dislave   long       7       NaN             NaN    complex     pseudo
# 4      enslike   long       7       NaN             NaN    complex     pseudo
# 5      enspect   long       7       NaN             NaN    complex     pseudo
# 6      fatalue   long       7       NaN             NaN    complex     pseudo
# 7      fatcher   long       7       NaN             NaN    complex     pseudo
# 8      immover   long       7       NaN             NaN    complex     pseudo
# 9      inslave   long       7       NaN             NaN    complex     pseudo
# 10     inslike   long       7       NaN             NaN    complex     pseudo
# 11     modalue   long       7       NaN             NaN    complex     pseudo
# 12     movally   long       7       NaN             NaN    complex     pseudo
# 13     movalue   long       7       NaN             NaN    complex     pseudo
# 14     nonsory   long       7       NaN             NaN    complex     pseudo
# 15     nonstor   long       7       NaN             NaN    complex     pseudo
# 16     reactop   long       7       NaN             NaN    complex     pseudo
# 17     rearful   long       7       NaN             NaN    complex     pseudo
# 18     recoder   long       7       NaN             NaN    complex     pseudo
# 19     remoral   long       7       NaN             NaN    complex     pseudo
# 20     rensory   long       7       NaN             NaN    complex     pseudo
# 21     renstop   long       7       NaN             NaN    complex     pseudo
# 22     renstor   long       7       NaN             NaN    complex     pseudo
# 23     senewal   long       7       NaN             NaN    complex     pseudo
# 24     senstop   long       7       NaN             NaN    complex     pseudo
# 25     senstor   long       7       NaN             NaN    complex     pseudo
# 26     teactop   long       7       NaN             NaN    complex     pseudo
# 27     teactor   long       7       NaN             NaN    complex     pseudo
# 28     tenewal   long       7       NaN             NaN    complex     pseudo
# 29     tensory   long       7       NaN             NaN    complex     pseudo
# 30     tenstop   long       7       NaN             NaN    complex     pseudo
# 31     tenstor   long       7       NaN             NaN    complex     pseudo
# 32     watally   long       7       NaN             NaN    complex     pseudo
# 33     watalue   long       7       NaN             NaN    complex     pseudo
# 34    dishaven   long       8       NaN             NaN    complex     pseudo
# 35    dishonal   long       8       NaN             NaN    complex     pseudo
# 36    egoisely   long       8       NaN             NaN    complex     pseudo
# 37    egoistep   long       8       NaN             NaN    complex     pseudo
# 38    egoister   long       8       NaN             NaN    complex     pseudo
# 39    entanize   long       8       NaN             NaN    complex     pseudo
# 40    fourness   long       8       NaN             NaN    complex     pseudo
# 41    fourtive   long       8       NaN             NaN    complex     pseudo
# 42    impolder   long       8       NaN             NaN    complex     pseudo
# 43    overster   long       8       NaN             NaN    complex     pseudo
# 44    overstic   long       8       NaN             NaN    complex     pseudo
# 45    reimporm   long       8       NaN             NaN    complex     pseudo
# 46    reustful   long       8       NaN             NaN    complex     pseudo
# 47    reustler   long       8       NaN             NaN    complex     pseudo
# 48    searless   long       8       NaN             NaN    complex     pseudo
# 49    seasonor   long       8       NaN             NaN    complex     pseudo
# 50    sourtive   long       8       NaN             NaN    complex     pseudo
# 51    sprictep   long       8       NaN             NaN    complex     pseudo
# 52    spricter   long       8       NaN             NaN    complex     pseudo
# 53    sprindly   long       8       NaN             NaN    complex     pseudo
# 54    sprintep   long       8       NaN             NaN    complex     pseudo
# 55    strictep   long       8       NaN             NaN    complex     pseudo
# 56    strindly   long       8       NaN             NaN    complex     pseudo
# 57    strintep   long       8       NaN             NaN    complex     pseudo
# 58    strinter   long       8       NaN             NaN    complex     pseudo
# 59    teasonal   long       8       NaN             NaN    complex     pseudo
# 60    teasonor   long       8       NaN             NaN    complex     pseudo
# 61    trusable   long       8       NaN             NaN    complex     pseudo
# 62    trustler   long       8       NaN             NaN    complex     pseudo
# 63    uninfort   long       8       NaN             NaN    complex     pseudo
# 64    unkintep   long       8       NaN             NaN    complex     pseudo
# 65    unkinter   long       8       NaN             NaN    complex     pseudo
# 66    unshonal   long       8       NaN             NaN    complex     pseudo
# 67    unshonor   long       8       NaN             NaN    complex     pseudo
# 68    unwistep   long       8       NaN             NaN    complex     pseudo
# 69    unwister   long       8       NaN             NaN    complex     pseudo
# 70    unwistic   long       8       NaN             NaN    complex     pseudo
# 71    upholite   long       8       NaN             NaN    complex     pseudo
# 72    womangle   long       8       NaN             NaN    complex     pseudo
# 73    wrestful   long       8       NaN             NaN    complex     pseudo
# 74   clearally   long       9       NaN             NaN    complex     pseudo
# 75   cleartile   long       9       NaN             NaN    complex     pseudo
# 76   deodeness   long       9       NaN             NaN    complex     pseudo
# 77   deodenest   long       9       NaN             NaN    complex     pseudo
# 78   deodorism   long       9       NaN             NaN    complex     pseudo
# 79   deodorist   long       9       NaN             NaN    complex     pseudo
# 80   deoutsell   long       9       NaN             NaN    complex     pseudo
# 81   discreach   long       9       NaN             NaN    complex     pseudo
# 82   discreact   long       9       NaN             NaN    complex     pseudo
# 83   discreate   long       9       NaN             NaN    complex     pseudo
# 84   dishfully   long       9       NaN             NaN    complex     pseudo
# 85   disreport   long       9       NaN             NaN    complex     pseudo
# 86   distfully   long       9       NaN             NaN    complex     pseudo
# 87   formaline   long       9       NaN             NaN    complex     pseudo
# 88   immerlity   long       9       NaN             NaN    complex     pseudo
# 89   immerlize   long       9       NaN             NaN    complex     pseudo
# 90   immerpass   long       9       NaN             NaN    complex     pseudo
# 91   immersold   long       9       NaN             NaN    complex     pseudo
# 92   immertile   long       9       NaN             NaN    complex     pseudo
# 93   immorance   long       9       NaN             NaN    complex     pseudo
# 94   inferline   long       9       NaN             NaN    complex     pseudo
# 95   inferlity   long       9       NaN             NaN    complex     pseudo
# 96   inferpass   long       9       NaN             NaN    complex     pseudo
# 97   infersion   long       9       NaN             NaN    complex     pseudo
# 98   infersold   long       9       NaN             NaN    complex     pseudo
# 99   miscreact   long       9       NaN             NaN    complex     pseudo
# 100  misembark   long       9       NaN             NaN    complex     pseudo
# 101  misembody   long       9       NaN             NaN    complex     pseudo
# 102  mishfully   long       9       NaN             NaN    complex     pseudo
# 103  mistfully   long       9       NaN             NaN    complex     pseudo
# 104  normaline   long       9       NaN             NaN    complex     pseudo
# 105  overiline   long       9       NaN             NaN    complex     pseudo
# 106  overility   long       9       NaN             NaN    complex     pseudo
# 107  overilize   long       9       NaN             NaN    complex     pseudo
# 108  overreate   long       9       NaN             NaN    complex     pseudo
# 109  overredit   long       9       NaN             NaN    complex     pseudo
# 110  pitlessly   long       9       NaN             NaN    complex     pseudo
# 111  procreach   long       9       NaN             NaN    complex     pseudo
# 112  procreact   long       9       NaN             NaN    complex     pseudo
# 113  procredit   long       9       NaN             NaN    complex     pseudo
# 114  redefully   long       9       NaN             NaN    complex     pseudo
# 115  rederline   long       9       NaN             NaN    complex     pseudo
# 116  rederlity   long       9       NaN             NaN    complex     pseudo
# 117  rederlize   long       9       NaN             NaN    complex     pseudo
# 118  rederpass   long       9       NaN             NaN    complex     pseudo
# 119  redersion   long       9       NaN             NaN    complex     pseudo
# 120  redersold   long       9       NaN             NaN    complex     pseudo
# 121  redertile   long       9       NaN             NaN    complex     pseudo
# 122  reimbural   long       9       NaN             NaN    complex     pseudo
# 123  reinstake   long       9       NaN             NaN    complex     pseudo
# 124  reirdness   long       9       NaN             NaN    complex     pseudo
# 125  remindful   long       9       NaN             NaN    complex     pseudo
# 126  remistate   long       9       NaN             NaN    complex     pseudo
# 127  reodeness   long       9       NaN             NaN    complex     pseudo
# 128  reodenest   long       9       NaN             NaN    complex     pseudo
# 129  reodorism   long       9       NaN             NaN    complex     pseudo
# 130  reodorize   long       9       NaN             NaN    complex     pseudo
# 131  reodormly   long       9       NaN             NaN    complex     pseudo
# 132  steriline   long       9       NaN             NaN    complex     pseudo
# 133  sterreach   long       9       NaN             NaN    complex     pseudo
# 134  sterreact   long       9       NaN             NaN    complex     pseudo
# 135  sterreate   long       9       NaN             NaN    complex     pseudo
# 136  sterredit   long       9       NaN             NaN    complex     pseudo
# 137  tattooism   long       9       NaN             NaN    complex     pseudo
# 138  tensenest   long       9       NaN             NaN    complex     pseudo
# 139  tuneflate   long       9       NaN             NaN    complex     pseudo
# 140  undeflate   long       9       NaN             NaN    complex     pseudo
# 141  undefully   long       9       NaN             NaN    complex     pseudo
# 142  underlity   long       9       NaN             NaN    complex     pseudo
# 143  undersion   long       9       NaN             NaN    complex     pseudo
# 144  undertile   long       9       NaN             NaN    complex     pseudo
# 145  unearally   long       9       NaN             NaN    complex     pseudo
# 146  unearance   long       9       NaN             NaN    complex     pseudo
# 147  uneartile   long       9       NaN             NaN    complex     pseudo
# 148  uniforist   long       9       NaN             NaN    complex     pseudo
# 149  unifority   long       9       NaN             NaN    complex     pseudo
# 150  uniforize   long       9       NaN             NaN    complex     pseudo
# 151  unmistake   long       9       NaN             NaN    complex     pseudo
# 152  unmistate   long       9       NaN             NaN    complex     pseudo
# 153  unnaturse   long       9       NaN             NaN    complex     pseudo
# 154  vulgarist   long       9       NaN             NaN    complex     pseudo
# 155  vulgarize   long       9       NaN             NaN    complex     pseudo
# 156  wakeflate   long       9       NaN             NaN    complex     pseudo
# 157  weimbural   long       9       NaN             NaN    complex     pseudo
# 158  weimburse   long       9       NaN             NaN    complex     pseudo
# 159  weinforce   long       9       NaN             NaN    complex     pseudo
# 160  weinstake   long       9       NaN             NaN    complex     pseudo
# 161  weinstate   long       9       NaN             NaN    complex     pseudo
# 162  weirdnest   long       9       NaN             NaN    complex     pseudo
# 163  wiscreact   long       9       NaN             NaN    complex     pseudo
# 164  wiscreate   long       9       NaN             NaN    complex     pseudo
# 165  wiscredit   long       9       NaN             NaN    complex     pseudo
# 166  wisembark   long       9       NaN             NaN    complex     pseudo
# 167  wisembody   long       9       NaN             NaN    complex     pseudo
# 168  wisreport   long       9       NaN             NaN    complex     pseudo
# 169  witifully   long       9       NaN             NaN    complex     pseudo
# 170  woodority   long       9       NaN             NaN    complex     pseudo
# 171  woodorize   long       9       NaN             NaN    complex     pseudo
# 172  woodormly   long       9       NaN             NaN    complex     pseudo
# 173  yellowess   long       9       NaN             NaN    complex     pseudo
# 174    decycle   long       7       NaN             NaN    complex     pseudo
# 175    dislave   long       7       NaN             NaN    complex     pseudo
# 176    enslike   long       7       NaN             NaN    complex     pseudo
# 177    enspect   long       7       NaN             NaN    complex     pseudo
# 178    fatalue   long       7       NaN             NaN    complex     pseudo
# 179    fatcher   long       7       NaN             NaN    complex     pseudo
# 180    immover   long       7       NaN             NaN    complex     pseudo
# 181    nonsory   long       7       NaN             NaN    complex     pseudo
# 182    rearful   long       7       NaN             NaN    complex     pseudo
# 183    recoder   long       7       NaN             NaN    complex     pseudo
# 184    remoral   long       7       NaN             NaN    complex     pseudo
# 185    senstop   long       7       NaN             NaN    complex     pseudo
# 186    teactor   long       7       NaN             NaN    complex     pseudo
# 187    tensory   long       7       NaN             NaN    complex     pseudo
# 188    watally   long       7       NaN             NaN    complex     pseudo
# 189   dishaven   long       8       NaN             NaN    complex     pseudo
# 190   dishonal   long       8       NaN             NaN    complex     pseudo
# 191   egoisely   long       8       NaN             NaN    complex     pseudo
# 192   entanize   long       8       NaN             NaN    complex     pseudo
# 193   fourtive   long       8       NaN             NaN    complex     pseudo
# 194   overster   long       8       NaN             NaN    complex     pseudo
# 195   reustler   long       8       NaN             NaN    complex     pseudo
# 196   searless   long       8       NaN             NaN    complex     pseudo
# 197   seasonor   long       8       NaN             NaN    complex     pseudo
# 198   sprindly   long       8       NaN             NaN    complex     pseudo
# 199   teasonal   long       8       NaN             NaN    complex     pseudo
# 200   uninfort   long       8       NaN             NaN    complex     pseudo
# 201   unshonor   long       8       NaN             NaN    complex     pseudo
# 202   upholite   long       8       NaN             NaN    complex     pseudo
# 203   wrestful   long       8       NaN             NaN    complex     pseudo
# 204  clearally   long       9       NaN             NaN    complex     pseudo
# 205  deodorism   long       9       NaN             NaN    complex     pseudo
# 206  discreate   long       9       NaN             NaN    complex     pseudo
# 207  misembark   long       9       NaN             NaN    complex     pseudo
# 208  mishfully   long       9       NaN             NaN    complex     pseudo
# 209  overility   long       9       NaN             NaN    complex     pseudo
# 210  procreact   long       9       NaN             NaN    complex     pseudo
# 211  redersion   long       9       NaN             NaN    complex     pseudo
# 212  reimbural   long       9       NaN             NaN    complex     pseudo
# 213  remindful   long       9       NaN             NaN    complex     pseudo
# 214  tensenest   long       9       NaN             NaN    complex     pseudo
# 215  unifority   long       9       NaN             NaN    complex     pseudo
# 216  weinforce   long       9       NaN             NaN    complex     pseudo
# 217  witifully   long       9       NaN             NaN    complex     pseudo
# 218  woodorize   long       9       NaN             NaN    complex     pseudo
# 0      addreat   long       7       NaN             NaN     simple     pseudo
# 1      advange   long       7       NaN             NaN     simple     pseudo
# 2      advanna   long       7       NaN             NaN     simple     pseudo
# 3      afflity   long       7       NaN             NaN     simple     pseudo
# 4      ailence   long       7       NaN             NaN     simple     pseudo
# 5      aillage   long       7       NaN             NaN     simple     pseudo
# 6      airsute   long       7       NaN             NaN     simple     pseudo
# 7      allenue   long       7       NaN             NaN     simple     pseudo
# 8      alleron   long       7       NaN             NaN     simple     pseudo
# 9      amaland   long       7       NaN             NaN     simple     pseudo
# 10     amalanx   long       7       NaN             NaN     simple     pseudo
# 11     amalict   long       7       NaN             NaN     simple     pseudo
# 12     amallow   long       7       NaN             NaN     simple     pseudo
# ...
# 91             NaN                          [AH1, N, T, IY0]
# 92             NaN                       [Y, UW1, S, AH0, N]
# 93             NaN                          [W, AY1, AA0, R]
# 94             NaN                               [W, IY1, N]
# 95             NaN                               [W, ER1, N]
# 96             NaN                          [W, OW1, D, OW0]
# 97             NaN                               [W, AO1, R]
# 98             NaN                          [W, AO1, R, IY0]
# 99             NaN                          [W, OW1, Z, IY0]
# 100            NaN                        [EY1, B, IY0, ER0]
# 101            NaN                       [AE1, K, T, L, IY0]
# 102            NaN                          [AE1, K, T, OY0]
# 103            NaN                     [AH0, M, AO1, N, IY0]
# 104            NaN                               [B, IY1, D]
# 105            NaN                       [B, EH1, B, AH0, N]
# 106            NaN                       [B, EH1, B, AH0, T]
# 107            NaN                            [B, ER1, T, S]
# 108            NaN                          [B, IY1, S, ER0]
# 109            NaN                       [B, IY1, S, IY0, Z]
# 110            NaN                       [B, EH1, T, IH0, T]
# 111            NaN                          [B, EH1, T, ER0]
# 112            NaN                         [B, L, AE1, K, T]
# 113            NaN                       [B, L, UW1, L, AH0]
# 114            NaN                          [B, OW1, L, ER0]
# 115            NaN                          [B, OW1, Z, ER0]
# 116            NaN                            [B, OW1, Z, S]
# 117            NaN                             [D, EY1, ER0]
# 118            NaN                          [D, EY1, M, ER0]
# 119            NaN                               [D, AW1, Z]
# 120            NaN                          [D, EY1, L, IY0]
# 121            NaN                                  [IY1, W]
# 122            NaN                             [IY1, L, ER0]
# 123            NaN                               [IY1, L, Z]
# 124            NaN                               [IY1, M, Z]
# 125            NaN                               [ER1, T, S]
# 126            NaN                          [IH1, R, AH0, T]
# 127            NaN                             [IY1, T, IY0]
# 128            NaN                                [OW1, ER0]
# 129            NaN                          [Y, UW1, L, IY0]
# 130            NaN                                [AY1, ER0]
# 131            NaN                               [IY1, L, Z]
# 132            NaN                          [EH0, N, EY1, D]
# 133            NaN                       [EH1, N, T, W, IY0]
# 134            NaN                          [EH1, N, T, OY0]
# 135            NaN                          [EH1, N, Z, IY0]
# 136            NaN                       [EH1, N, Z, IH0, T]
# 137            NaN                            [F, L, EY1, D]
# 138            NaN                         [F, L, AA1, R, Z]
# 139            NaN                            [G, EY1, L, Z]
# 140            NaN                          [G, AE1, L, AH0]
# 141            NaN                          [G, AE1, M, IY0]
# 142            NaN                       [G, AA1, R, L, AH0]
# 143            NaN                         [HH, EH1, P, IY0]
# 144            NaN                      [HH, EH1, R, AH0, L]
# 145            NaN                           [HH, ER1, L, Z]
# 146            NaN                         [HH, EH1, S, ER0]
# 147            NaN                         [HH, IY1, T, ER0]
# 148            NaN                         [HH, AH1, N, IY0]
# 149            NaN                          [L, AO1, L, IY0]
# 150            NaN                       [L, AY1, D, AH0, P]
# 151            NaN                       [L, IH1, V, IH0, T]
# 152            NaN                          [L, AO1, N, IY0]
# 153            NaN                       [L, OW1, S, AH0, T]
# 154            NaN                             [AA1, D, IY0]
# 155            NaN                          [P, AE1, M, IY0]
# 156            NaN                          [P, AE1, T, IY0]
# 157            NaN                             [P, AW1, ER0]
# 158            NaN                         [P, AE1, L, K, T]
# 159            NaN                         [P, L, AE1, G, Z]
# 160            NaN                         [P, L, AA1, R, Z]
# 161            NaN                            [P, L, UW1, D]
# 162            NaN                            [P, L, UW1, Z]
# 163            NaN                               [R, EH1, D]
# 164            NaN                       [R, EH1, B, AH0, G]
# 165            NaN                          [R, EH1, F, IY0]
# 166            NaN                       [R, EH1, F, IH0, P]
# 167            NaN                       [R, EH1, R, L, IY0]
# 168            NaN                          [R, IY1, Z, ER0]
# 169            NaN                       [R, EH1, T, L, IY0]
# 170            NaN                          [R, IY1, T, ER0]
# 171            NaN                               [R, OY1, Z]
# 172            NaN                              [R, AO1, NG]
# 173            NaN                          [R, OW1, Z, ER0]
# 174            NaN                              [SH, AY1, Z]
# 175            NaN                            [S, K, AY1, D]
# 176            NaN                       [S, K, IY1, W, EH0]
# 177            NaN                       [S, K, AY1, L, IY0]
# 178            NaN                          [S, AH1, N, ER0]
# 179            NaN                       [AH0, N, AE1, K, T]
# 180            NaN                          [AH0, N, EY1, D]
# 181            NaN                      [Y, UW1, N, IH0, JH]
# 182            NaN                    [Y, UW1, N, AH0, G, Z]
# 183            NaN                       [AH0, N, D, IH1, T]
# 184            NaN                      [AH0, N, JH, AO1, R]
# 185            NaN                         [AH0, N, JH, OY1]
# 186            NaN                       [AH1, N, T, L, AH0]
# 187            NaN                          [AH1, N, Z, IY0]
# 188            NaN                       [AH0, N, S, AY1, T]
# 189            NaN                             [AH0, P, AY1]
# 190            NaN                          [AH1, P, AH0, S]
# 191            NaN                          [AH1, P, AH0, T]
# 192            NaN                    [Y, UW1, Z, AE0, D, Z]
# 193            NaN                    [Y, UW1, S, AE0, G, Z]
# 194            NaN                       [Y, UW1, Z, ER0, Z]
# 195            NaN                               [W, IY1, Z]
# 196            NaN                       [W, EH1, B, AH0, T]
# 197            NaN                          [W, EH1, T, ER0]
# 198            NaN                          [W, AY1, V, ER0]
# 199            NaN                       [W, IH1, V, IH0, T]
# 200            NaN                       [AH0, B, R, AY1, K]
# 201            NaN                       [AH0, B, R, UW1, T]
# 202            NaN                       [EY1, B, R, AH0, S]
# 203            NaN                       [AE1, K, R, OW0, D]
# 204            NaN                  [AH0, K, R, OY1, IH0, K]
# 205            NaN                       [AH0, K, R, UW1, T]
# 206            NaN                          [AE1, L, OW0, N]
# 207            NaN                   [AO1, ER0, AH0, L, IY0]
# 208            NaN                    [AH0, W, AO1, R, T, S]
# 209            NaN                          [B, ER0, IY1, D]
# 210            NaN                    [B, EH1, R, AH0, L, Z]
# 211            NaN                       [B, IH0, F, IH1, L]
# 212            NaN                       [B, EH1, F, ER0, T]
# 213            NaN               [B, EH1, F, Y, UW0, AH0, L]
# 214            NaN                  [B, IH0, M, OW1, AH0, D]
# 215            NaN                       [B, L, EY1, M, ER0]
# 216            NaN                         [B, L, EY1, N, Z]
# 217            NaN                       [B, L, OW1, L, IY0]
# 218            NaN                      [B, R, AE1, N, T, S]
# 219            NaN                         [B, R, AY1, M, Z]
# 220            NaN                       [B, AY1, P, AH0, S]
# 221            NaN                         [K, AW1, N, D, Z]
# 222            NaN                      [K, R, IH1, N, T, S]
# 223            NaN                         [K, R, AY1, T, S]
# 224            NaN                         [D, IH1, R, D, Z]
# 225            NaN                            [D, ER1, T, S]
# 226            NaN                       [D, IH1, S, OW0, Z]
# 227            NaN                          [IY1, Z, AH0, L]
# 228            NaN                    [IH0, N, K, AA1, S, K]
# 229            NaN                    [EH0, N, K, AE1, S, T]
# 230            NaN                    [IH0, N, K, L, AE1, D]
# 231            NaN                  [EH0, N, M, AA1, S, IY0]
# 232            NaN                       [EH1, N, M, AH0, S]
# 233            NaN                    [EH1, N, M, AH0, S, T]
# 234            NaN                    [EH1, N, R, AH0, L, Z]
# 235            NaN                       [EH0, N, T, UW1, T]
# 236            NaN                 [EH1, K, S, P, AO2, R, M]
# 237            NaN                    [EH1, K, S, P, ER0, Z]
# 238            NaN                         [F, L, EY1, N, Z]
# 239            NaN                      [F, L, AE1, N, T, S]
# 240            NaN                      [HH, EH1, R, OW0, S]
# 241            NaN                      [HH, OW1, T, ER0, Z]
# 242            NaN                       [IY1, K, OW0, N, Z]
# 243            NaN                    [IH0, M, P, AO1, R, M]
# 244            NaN                       [IH1, N, S, ER0, Z]
# 245            NaN                    [IH1, N, S, P, AE2, N]
# 246            NaN                       [L, EY1, B, L, IY0]
# 247            NaN                         [M, EY1, N, T, S]
# 248            NaN                            [M, EY1, Z, D]
# 249            NaN                    [M, IH0, S, AA1, R, M]
# 250            NaN                    [S, IH0, S, B, AA1, R]
# 251            NaN                    [M, IH1, S, T, IH0, L]
# 252            NaN                  [OW1, P, IY0, AE2, K, S]
# 253            NaN                       [AO0, R, EY1, N, Z]
# 254            NaN                    [AO1, R, AH0, N, T, S]
# 255            NaN                         [P, L, AE1, K, S]
# 256            NaN                        [P, R, IH1, NG, Z]
# 257            NaN                       [P, R, AY1, T, ER0]
# 258            NaN                         [P, R, AY1, T, S]
# 259            NaN                       [R, EH1, R, AH0, D]
# 260            NaN                      [R, EH1, R, IH0, SH]
# 261            NaN                         [R, AA1, R, M, Z]
# 262            NaN                       [R, IY0, K, EY1, S]
# 263            NaN                    [R, IY0, K, AE1, S, K]
# 264            NaN                  [R, EH1, F, AH0, L, IY0]
# 265            NaN                       [R, IY1, F, ER0, Z]
# 266            NaN                       [R, IY0, F, UW1, L]
# 267            NaN                    [R, IY0, F, Y, UW1, D]
# 268            NaN                    [R, IY0, EH1, R, T, S]
# 269            NaN                            [R, ER1, V, D]
# 270            NaN                       [R, IY0, T, AA1, M]
# 271            NaN                       [R, IY0, T, UW1, T]
# 272            NaN                     [S, ER0, OW1, IH0, K]
# 273            NaN                      [SH, AA1, R, L, IY0]
# 274            NaN                       [S, L, UW1, D, IY0]
# 275            NaN                    [S, N, AO1, R, L, IY0]
# 276            NaN                         [S, AW1, N, T, S]
# 277            NaN                    [S, P, EH1, N, L, IY0]
# 278            NaN                       [T, R, AE1, L, IY0]
# 279            NaN                         [T, R, EY1, N, Z]
# 280            NaN                    [AH1, N, B, OW2, L, D]
# 281            NaN                       [AH0, N, M, EY1, Z]
# 282            NaN                      [AH0, N, M, EH1, SH]
# 283            NaN                    [AH0, N, M, EH1, S, T]
# 284            NaN                      [AH0, N, R, EH1, SH]
# 285            NaN                      [AH1, N, R, IH0, CH]
# 286            NaN                       [AH0, N, S, ER0, Z]
# 287            NaN                      [AH0, P, HH, IY1, L]
# 288            NaN                       [AH0, P, OW1, L, T]
# 289            NaN                       [AH0, P, R, UW1, K]
# 290            NaN                       [W, EH1, R, AH0, D]
# 291            NaN                    [W, EH1, R, AH0, L, Z]
# 292            NaN                       [W, EH1, R, L, IY0]
# 293            NaN                         [W, AO1, R, M, Z]
# 294            NaN                    [W, AO1, T, AH0, L, Z]
# 295            NaN                       [W, EY1, T, L, IY0]
# 296            NaN                         [W, UW1, N, T, S]
# 297            NaN                            [R, AY1, M, Z]
# 298            NaN                       [Y, IY1, D, L, IY0]
# 299            NaN                         [Y, IH1, R, D, Z]
# 300            NaN                            [AA1, R, N, Z]
# 301            NaN                       [AE1, K, S, AH0, N]
# 302            NaN                              [D, EH1, TH]
# 303            NaN                             [IH1, R, IY0]
# 304            NaN                              [G, EH1, TH]
# 305            NaN                          [IH1, N, T, IY0]
# 306            NaN                          [L, EY1, Z, IY0]
# 307            NaN                          [AA1, K, S, ER0]
# 308            NaN                  [OW0, N, IY1, T, AH0, T]
# 309            NaN                               [P, AW1, N]
# 310            NaN                               [R, UW1, Z]
# 311            NaN                               [S, AO1, R]
# 312            NaN                       [Y, UW1, S, AH0, N]
# 313            NaN                          [W, AY1, AA0, R]
# 314            NaN                          [W, OW1, Z, IY0]
# 315            NaN                       [AE1, K, T, L, IY0]
# 316            NaN                       [B, EH1, B, AH0, T]
# 317            NaN                          [B, OW1, Z, ER0]
# 318            NaN                               [ER1, T, S]
# 319            NaN                          [EH1, N, T, OY0]
# 320            NaN                           [HH, ER1, L, Z]
# 321            NaN                          [L, AO1, N, IY0]
# 322            NaN                          [P, AE1, M, IY0]
# 323            NaN                         [P, AE1, L, K, T]
# 324            NaN                               [R, EH1, D]
# 325            NaN                       [R, EH1, B, AH0, G]
# 326            NaN                      [Y, UW1, N, IH0, JH]
# 327            NaN                         [AH0, N, JH, OY1]
# 328            NaN                       [W, EH1, B, AH0, T]
# 329            NaN                       [W, IH1, V, IH0, T]
# 330            NaN                       [AH0, B, R, UW1, T]
# 331            NaN               [B, EH1, F, Y, UW0, AH0, L]
# 332            NaN                  [B, IH0, M, OW1, AH0, D]
# 333            NaN                       [EH1, N, M, AH0, S]
# 334            NaN                    [EH1, K, S, P, ER0, Z]
# 335            NaN                    [M, IH0, S, AA1, R, M]
# 336            NaN                        [P, R, IH1, NG, Z]
# 337            NaN                       [R, IY0, T, AA1, M]
# 338            NaN                     [S, ER0, OW1, IH0, K]
# 339            NaN                    [S, P, EH1, N, L, IY0]
# 340            NaN                      [AH1, N, R, IH0, CH]
# 341            NaN                       [AH0, P, OW1, L, T]
# 342            NaN                    [W, EH1, R, AH0, L, Z]
# 343            NaN                       [W, EY1, T, L, IY0]
# 344            NaN                         [Y, IH1, R, D, Z]

# %%
import pandas as pd
from pathlib import Path

# Define the column names
columns = ['hidden_size', 'num_layers', 'dropout', 'learning_rate']
columns += [f'{loss_type}{1}-{i}' for i in range(1, 10) for loss_type in ['T', 'V']]
columns += [f'{loss_type}{i}' for i in range(2, 31) for loss_type in ['T', 'V']]

# Create the empty DataFrame
df = pd.DataFrame(columns=columns)

# Fill the DataFrame with sample hyperparameters and losses
df.loc['steve'] = [4, 2, 0.1, 0.001] + [0.0001] * 76
df.loc['john'] = [4, 2, 0.1, 0.001] + [0.0002] * 76
df.loc['david'] = [4, 2, 0.1, 0.001] + [0.0003] * 76

df
# # Establish path to data directory
# FILE_DIR = Path(__file__).resolve()
# DATA_DIR = FILE_DIR.parent.parent.parent / "data"
# DATA_DIR.mkdir(exist_ok=True)

# # Save the DataFrame to a CSV file
# df.to_csv(DATA_DIR / "grid_search.csv", index=False)
# Out:
#        hidden_size  num_layers  dropout  learning_rate    T1-1    V1-1  \
# steve          4.0         2.0      0.1          0.001  0.0001  0.0001
# john           4.0         2.0      0.1          0.001  0.0002  0.0002
# david          4.0         2.0      0.1          0.001  0.0003  0.0003
#
#          T1-2    V1-2    T1-3    V1-3  ...     T26     V26     T27     V27  \
# steve  0.0001  0.0001  0.0001  0.0001  ...  0.0001  0.0001  0.0001  0.0001
# john   0.0002  0.0002  0.0002  0.0002  ...  0.0002  0.0002  0.0002  0.0002
# david  0.0003  0.0003  0.0003  0.0003  ...  0.0003  0.0003  0.0003  0.0003
#
#           T28     V28     T29     V29     T30     V30
# steve  0.0001  0.0001  0.0001  0.0001  0.0001  0.0001
# john   0.0002  0.0002  0.0002  0.0002  0.0002  0.0002
# david  0.0003  0.0003  0.0003  0.0003  0.0003  0.0003
#
# [3 rows x 80 columns]

# %%
from train_repetition import grid_search_log

model = "e10_h4_l2_d0.1_r0.001"

train_losses = [0.0001] * 30
val_losses = [0.0002] * 30

grid_search_log(train_losses, val_losses, model)

# %%
# read grid_search.csv
import pandas as pd
df = pd.read_csv("grid_search.csv")
df
# Out:
#                    model  hidden_size  num_layers  ...     V28     V29     V30
# 0  e10_h4_l2_d0.1_r0.001            4           2  ...  0.0002  0.0002  0.0002
#
# [1 rows x 65 columns]
