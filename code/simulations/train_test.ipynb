# %%
import pandas as pd
from Phonemes import Phonemes
from test_repetition import test_repetition
from plots import parametric_plots

P = Phonemes()
model = "e5_h1_l2_d0.0_r0.05"
test_data = test_repetition(P, model)
parametric_plots(test_data, model)
# Out:
# Using MPS device
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 9
#       7 model = "e5_h1_l2_d0.0_r0.05"
#       8 test_data = test_repetition(D, model)
# ----> 9 parametric_plots(test_data, model)
#
# File ~/Desktop/single-word-processing-model/code/simulations/plots.py:111, in parametric_plots(df, model_name)
#     109 mask = (length_grouped['Dataset'] == dataset) & (length_grouped['Lexicality'] == lexicality) & (length_grouped['Morphology'] == morphology)
#     110 linestyle = '-' if dataset == 'Training' else '--'
# --> 111 color = colors[morphology] if lexicality == 'real' else colors['pseudo']
#     112 marker = 'o' if lexicality == 'real' else 's'
#     113 ax1.plot(length_grouped[mask]['Length'],
#     114         length_grouped[mask]['Edit Distance'],
#     115         linestyle=linestyle,
#     116         color=color,
# ...

# %%
from train_repetition import train_repetition

eval_data = train_repetition(D, hidden_size=2)
# Out:
# 3_2_1_0.0_0.005
# Epoch 1: T Loss: 1.3423 V Loss: 0.8154 Time: 228.69s
# Epoch 2: T Loss: 0.6864 V Loss: 0.5256 Time: 225.32s
# Epoch 3: T Loss: 0.4688 V Loss: 0.3536 Time: 227.58s
# Timing Summary:
# ------------------------------------------------------------
# Operation                      Total Time (s)  Avg Time (s)
# ------------------------------------------------------------
# Encoder Forward Pass                  51.172s         0.000s
# Decoder Forward Pass                  34.992s         0.000s
# Backward Pass                        445.698s         0.003s
# Validation                            32.568s        10.856s
# Testing                                2.761s         2.761s

# %%
pd.set_option('display.max_rows', 2000)
eval_data
# Out:
#           Word  Length Frequency  Zipf Frequency Morph Complexity Lexicality  \
# 0      bathmat       7       low            1.55          complex       real
# 1      decoder       7       low            2.84          complex       real
# 2      defiant       7       low            3.21          complex       real
# 3      padlock       7       low            2.68          complex       real
# 4      immoral       7       low            3.46          complex       real
# 5      nonstop       7       low            3.37          complex       real
# 6      parasol       7       low            2.63          complex       real
# 7      reactor       7       low            3.83          complex       real
# 8      recycle       7       low            3.35          complex       real
# 9      reenact       7       low            2.42          complex       real
# 10     reliant       7       low            3.41          complex       real
# ...

# %%
from test_repetition import test_repetition

model = "e5_h1_l2_d0.0_r0.05"
test_data = test_repetition(D, model)

from plots import parametric_plots

parametric_plots(test_data, model)
# Out:
# Using MPS device

# %%
from plots import parametric_plots

parametric_plots(test_data, model)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Split'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 from plots import parametric_plots
# ...
